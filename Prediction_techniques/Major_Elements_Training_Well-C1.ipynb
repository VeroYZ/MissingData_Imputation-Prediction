# %%
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import OrdinalEncoder

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm.sklearn import LGBMRegressor

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ParameterGrid
from sklearn.inspection import permutation_importance
import multiprocessing

from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Preprocessing

# %%
Well_C1=pd.read_excel("well_C1.xlsx")

Train_Wells={}

for i in list(range(1,5)):
    path="TEST-"+ str(list(range(5)))
    file= glob.glob(path + ".xlsx")

    Train_Wells['TEST_'+ str(i)] = pd.read_excel(file[i-1])
    
    i=i+1

# %%
Well_C1=Well_C1.drop(['WELL','LOI', 'Cr2O3', 'V2O5'], axis=1)

# %% [markdown]
# ### Categorical features to numerical

# %%
def ordinal_encoder(test):
    well_encoder = OrdinalEncoder(categories=[Train_Wells[test]['WELL'].unique()])

    well_encoder.fit(Train_Wells[test][["WELL"]])
    Train_Wells[test][["Well"]] = well_encoder.transform(Train_Wells[test][["WELL"]])
    Train_Wells[test] = Train_Wells[test].drop('WELL', axis=1)
    
    Well_C1["Well"] = Train_Wells[test]['Well'].nunique()

# %%
tests=['TEST_1','TEST_2','TEST_3','TEST_4']
traces=['SO3', 'Ba', 'Cu', 'Ga', 'Mo', 'Nb', 'Ni','Pb', 'Rb', 'Sr', 'Th', 'U', 'Y', 'Zn', 'Zr', 'Cr', 'V']
Tests={}
for test in tests:
    ordinal_encoder(test)
    Tests[test] = Train_Wells[test].drop(traces, axis=1)
    Tests['C1_'+ test] = Well_C1.copy()

# %% [markdown]
# ## Random Forest

# %%
C1_depth=Well_C1.loc[:,'Depth']

# %%
def Random_Forest(test, C1_test):
    
    wells_scores = pd.DataFrame()
    C1_scores = pd.DataFrame()
    pred = pd.DataFrame(C1_depth)
        
    for col in Tests[test].iloc[:,1:-1]:
        X = Tests[test].drop([col], axis=1)
        y = Tests[test][col]
        
                
        X_train, X_test, y_train, y_test = train_test_split(
                                            X,
                                            y,
                                            train_size   = 0.7,
                                            random_state = 123,
                                            shuffle      = True
                                        )        
    
        # Evaluated Hyperparameters
    
        param_grid = {'n_estimators': [30,70,150],
                      'max_features': [5, 10, 25],
                      'max_depth'   : [None, 3, 10, 20]
                     }

        # Grid
    
        grid = GridSearchCV(
                estimator  = RandomForestRegressor(random_state = 123),
                param_grid = param_grid,
                scoring    = 'neg_root_mean_squared_error',
                n_jobs     = - 1,
                cv         = RepeatedKFold(n_splits=5, n_repeats=3, random_state=123), 
                refit      = True,
                verbose    = 0,
                return_train_score = True
               )

        grid.fit(X = X_train, y = y_train)

        print("Final model best hyperparameters: ")        
        print("")       
        print(grid.best_params_, ":", grid.best_score_, grid.scoring)
        print("")
    
        # Test scores
        
        final_model = grid.best_estimator_
        predictions = final_model.predict(X = X_test)
        
        rmse = mean_squared_error(
                y_true  = y_test,
                y_pred  = predictions,
                squared = False
               )
                
        nrmse = rmse/(y_test.max()-y_test.min())
        
        R2 = r2_score(y_test, predictions)        
        
        print("Wells Test Scores")
        print(f"{col}:")
        print(f"RMSE: {rmse}")
        print(f"NRMSE: {nrmse}")        
        print(f"R2 score: {R2}")
        print("")
        print("")
        
                  
        # Save well test validation
                
        wells_scores = wells_scores.append({"y_hat": col, f"rmse_RF_{test}": rmse, f"nrmse_RF_{test}": nrmse,
                                           f"R2_RF_{test}": R2}, ignore_index=True)
                
        wells_scores.to_excel(f"Wells_Mayor_scores_RF_{test}.xlsx")         
    
        
        # WELL C1 MAYOR ELEMENTS PREDICTIONS 
                
        X_test_C1 = Tests[C1_test].drop([col], axis=1)
        y_test_C1 = Tests[C1_test][col]
    
        C1_predictions = final_model.predict(X_test_C1) 
    
        rmse_C1 = mean_squared_error(
                    y_true  = y_test_C1,
                    y_pred  = C1_predictions,
                    squared = False
                   )
                
        nrmse_C1 = rmse_C1/(y_test_C1.max()-y_test_C1.min())
        
        R2_C1 = r2_score(y_test_C1, C1_predictions) 
                
        
        print("C1 Prediction Scores")
        print(f"{col}:")
        print(f"RMSE: {rmse_C1}")
        print(f"NRMSE: {nrmse_C1}")        
        print(f"R2 score: {R2_C1}")
        print("")
        print("")
                
         
        # Save C1 predicted curves
        
        C1_pred = pd.DataFrame()

        C1_pred = C1_pred.assign(Predictions = C1_predictions.flatten().tolist())        
                
        pred=pd.concat([pred,C1_pred],axis=1)
        
        pred.columns=pred.columns.str.replace('Predictions', f"{col}")
        
        pred.to_excel(f"C1_Mayor_pred_RF_{test}.xlsx")     
        
        
        # Save C1 predictions scores
    
        C1_scores = C1_scores.append({'y_hat':col,f"rmse_RF_{test}": rmse_C1, f"nrmse_RF_{test}": nrmse_C1,
                                 f"R2_RF_{test}": R2_C1}, ignore_index=True)
        
        C1_scores.to_excel(f"C1_Mayor_scores_RF_{test}.xlsx")         
                
    
        print("")
                
    print(f"Well {test} validation")
    print(wells_scores)
    print("")
    print("")
    print(f"C1 {test} scores")
    print(C1_scores)

# %%
Random_Forest('TEST_1', 'C1_TEST_1')
# Out:
# Final model best hyperparameters:
#
# {'max_depth': 10, 'max_features': 5, 'n_estimators': 150} : -0.33756504576820184 neg_root_mean_squared_error
#
# Wells Test Scores
# Al2O3:
# RMSE: 0.2681016230040316
# NRMSE: 0.020790888280014706
# R2 score: 0.9826982971589855
#
#
# C1 Prediction Scores
# Al2O3:
# RMSE: 0.7371085573263692
# NRMSE: 0.04697951289524342
# R2 score: 0.9263074355294078
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': None, 'max_features': 5, 'n_estimators': 150} : -1.7791619861755563 neg_root_mean_squared_error
#
# Wells Test Scores
# SiO2:
# RMSE: 1.4003630431716758
# NRMSE: 0.02919206763573817
# R2 score: 0.9685839865471649
#
#
# C1 Prediction Scores
# SiO2:
# RMSE: 4.817915391690907
# NRMSE: 0.0918047902380127
# R2 score: 0.8461353144428179
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 10, 'max_features': 5, 'n_estimators': 150} : -0.025898083451094314 neg_root_mean_squared_error
#
# Wells Test Scores
# TiO2:
# RMSE: 0.03166529100932136
# NRMSE: 0.04623952776583484
# R2 score: 0.9095671383208707
#
#
# C1 Prediction Scores
# TiO2:
# RMSE: 0.0756939178201479
# NRMSE: 0.1513878356402958
# R2 score: 0.5484422321412967
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 10, 'max_features': 5, 'n_estimators': 150} : -0.1693097681856609 neg_root_mean_squared_error
#
# Wells Test Scores
# Fe2O3:
# RMSE: 0.15537436670900984
# NRMSE: 0.06243595309258032
# R2 score: 0.9036673635091448
#
#
# C1 Prediction Scores
# Fe2O3:
# RMSE: 0.8808551647495129
# NRMSE: 0.11855385797436244
# R2 score: 0.30187203097746196
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 20, 'max_features': 5, 'n_estimators': 150} : -0.00918674171546781 neg_root_mean_squared_error
#
# Wells Test Scores
# MnO:
# RMSE: 0.0036332295786011097
# NRMSE: 0.06221283525001901
# R2 score: 0.8464542393890642
#
#
# C1 Prediction Scores
# MnO:
# RMSE: 0.026571422998259944
# NRMSE: 0.1476190166569997
# R2 score: 0.2926777197983603
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': None, 'max_features': 25, 'n_estimators': 70} : -0.34189555853819337 neg_root_mean_squared_error
#
# Wells Test Scores
# MgO:
# RMSE: 0.26914361359892575
# NRMSE: 0.11907376138623715
# R2 score: 0.5957020080740667
#
#
# C1 Prediction Scores
# MgO:
# RMSE: 1.9087387547688113
# NRMSE: 0.13264341589776313
# R2 score: 0.17328700196655855
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': None, 'max_features': 5, 'n_estimators': 150} : -1.241623225181985 neg_root_mean_squared_error
#
# Wells Test Scores
# CaO:
# RMSE: 1.1975240814813182
# NRMSE: 0.030384457311046553
# R2 score: 0.9757547123434259
#
#
# C1 Prediction Scores
# CaO:
# RMSE: 3.5591821291978945
# NRMSE: 0.08454114321135141
# R2 score: 0.8692643917131155
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 10, 'max_features': 10, 'n_estimators': 30} : -0.24468732855659384 neg_root_mean_squared_error
#
# Wells Test Scores
# Na2O:
# RMSE: 0.22773767745338216
# NRMSE: 0.06606722176387476
# R2 score: 0.8776826841386215
#
#
# C1 Prediction Scores
# Na2O:
# RMSE: 0.8573890311346686
# NRMSE: 0.42656170703217344
# R2 score: -2.783598589825594
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': None, 'max_features': 5, 'n_estimators': 150} : -0.1287131039386765 neg_root_mean_squared_error
#
# Wells Test Scores
# K2O:
# RMSE: 0.14220508171082494
# NRMSE: 0.04129714929484441
# R2 score: 0.9246806626369404
#
#
# C1 Prediction Scores
# K2O:
# RMSE: 0.21647626362029354
# NRMSE: 0.07097582413780117
# R2 score: 0.8435614615439225
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': None, 'max_features': 5, 'n_estimators': 150} : -0.07828695402383604 neg_root_mean_squared_error
#
# Wells Test Scores
# P2O5:
# RMSE: 0.06563205585473543
# NRMSE: 0.12979226739718674
# R2 score: 0.5230480736675562
#
#
# C1 Prediction Scores
# P2O5:
# RMSE: 0.20988198441566802
# NRMSE: 0.15546813660419856
# R2 score: 0.09928848767783316
#
#
#
# Well TEST_1 validation
#    y_hat  rmse_RF_TEST_1  nrmse_RF_TEST_1  R2_RF_TEST_1
# 0  Al2O3        0.268102         0.020791      0.982698
# 1   SiO2        1.400363         0.029192      0.968584
# 2   TiO2        0.031665         0.046240      0.909567
# 3  Fe2O3        0.155374         0.062436      0.903667
# 4    MnO        0.003633         0.062213      0.846454
# 5    MgO        0.269144         0.119074      0.595702
# 6    CaO        1.197524         0.030384      0.975755
# 7   Na2O        0.227738         0.066067      0.877683
# 8    K2O        0.142205         0.041297      0.924681
# 9   P2O5        0.065632         0.129792      0.523048
#
#
# C1 TEST_1 scores
#    y_hat  rmse_RF_TEST_1  nrmse_RF_TEST_1  R2_RF_TEST_1
# 0  Al2O3        0.737109         0.046980      0.926307
# 1   SiO2        4.817915         0.091805      0.846135
# 2   TiO2        0.075694         0.151388      0.548442
# 3  Fe2O3        0.880855         0.118554      0.301872
# 4    MnO        0.026571         0.147619      0.292678
# 5    MgO        1.908739         0.132643      0.173287
# 6    CaO        3.559182         0.084541      0.869264
# 7   Na2O        0.857389         0.426562     -2.783599
# 8    K2O        0.216476         0.070976      0.843561
# 9   P2O5        0.209882         0.155468      0.099288

# %%
Random_Forest('TEST_2', 'C1_TEST_2')
# Out:
# Final model best hyperparameters:
#
# {'max_depth': 10, 'max_features': 5, 'n_estimators': 150} : -0.366778146161944 neg_root_mean_squared_error
#
# Wells Test Scores
# Al2O3:
# RMSE: 0.3791612260025159
# NRMSE: 0.03386846810817543
# R2 score: 0.9609899017850667
#
#
# C1 Prediction Scores
# Al2O3:
# RMSE: 0.8928413090364804
# NRMSE: 0.05690511848543534
# R2 score: 0.8918791839417666
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': None, 'max_features': 5, 'n_estimators': 150} : -1.8938907510427334 neg_root_mean_squared_error
#
# Wells Test Scores
# SiO2:
# RMSE: 2.3150981692075896
# NRMSE: 0.04884484558314875
# R2 score: 0.9150256879588414
#
#
# C1 Prediction Scores
# SiO2:
# RMSE: 4.7717333796241
# NRMSE: 0.09092479763003239
# R2 score: 0.8490709096307181
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 20, 'max_features': 5, 'n_estimators': 150} : -0.026339960057896437 neg_root_mean_squared_error
#
# Wells Test Scores
# TiO2:
# RMSE: 0.030197571902869487
# NRMSE: 0.049524513165837614
# R2 score: 0.8831650833035147
#
#
# C1 Prediction Scores
# TiO2:
# RMSE: 0.052289536355341545
# NRMSE: 0.10457907271068309
# R2 score: 0.7845130714810136
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': None, 'max_features': 5, 'n_estimators': 150} : -0.13479876699040919 neg_root_mean_squared_error
#
# Wells Test Scores
# Fe2O3:
# RMSE: 0.18096390763833997
# NRMSE: 0.06308220017371631
# R2 score: 0.8856634571785913
#
#
# C1 Prediction Scores
# Fe2O3:
# RMSE: 0.8679299027795432
# NRMSE: 0.11681425340236114
# R2 score: 0.32220973008293674
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 10, 'max_features': 5, 'n_estimators': 150} : -0.0038865382184764216 neg_root_mean_squared_error
#
# Wells Test Scores
# MnO:
# RMSE: 0.00512632351726911
# NRMSE: 0.13120868997361426
# R2 score: 0.581243634091053
#
#
# C1 Prediction Scores
# MnO:
# RMSE: 0.031491244211776
# NRMSE: 0.1749513567320889
# R2 score: 0.006501188817214842
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': None, 'max_features': 25, 'n_estimators': 70} : -0.290593937985792 neg_root_mean_squared_error
#
# Wells Test Scores
# MgO:
# RMSE: 0.25851235498615877
# NRMSE: 0.10922903409226295
# R2 score: 0.6240006134581177
#
#
# C1 Prediction Scores
# MgO:
# RMSE: 2.074705705171657
# NRMSE: 0.14417690793409707
# R2 score: 0.023269419226851662
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 10, 'max_features': 10, 'n_estimators': 150} : -1.596284876637297 neg_root_mean_squared_error
#
# Wells Test Scores
# CaO:
# RMSE: 2.074608627050042
# NRMSE: 0.04980767315032923
# R2 score: 0.9263933544907006
#
#
# C1 Prediction Scores
# CaO:
# RMSE: 4.168678565150808
# NRMSE: 0.09901849323398593
# R2 score: 0.8206545818027388
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 10, 'max_features': 5, 'n_estimators': 150} : -0.25481563110263006 neg_root_mean_squared_error
#
# Wells Test Scores
# Na2O:
# RMSE: 0.32198082424478325
# NRMSE: 0.09493674661429598
# R2 score: 0.7119880724462742
#
#
# C1 Prediction Scores
# Na2O:
# RMSE: 0.4280662057151919
# NRMSE: 0.21296826154984674
# R2 score: 0.05687100866012973
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 10, 'max_features': 10, 'n_estimators': 70} : -0.12046160181832467 neg_root_mean_squared_error
#
# Wells Test Scores
# K2O:
# RMSE: 0.16033110573690076
# NRMSE: 0.05244892071605246
# R2 score: 0.88254037498818
#
#
# C1 Prediction Scores
# K2O:
# RMSE: 0.16412684532028254
# NRMSE: 0.05381208043287953
# R2 score: 0.9100745898979875
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 20, 'max_features': 5, 'n_estimators': 150} : -0.07187564253524469 neg_root_mean_squared_error
#
# Wells Test Scores
# P2O5:
# RMSE: 0.07677987231517493
# NRMSE: 0.1195389573644324
# R2 score: 0.4904402459569166
#
#
# C1 Prediction Scores
# P2O5:
# RMSE: 0.19486624606102895
# NRMSE: 0.14434536745261406
# R2 score: 0.22355870020685198
#
#
#
# Well TEST_2 validation
#    y_hat  rmse_RF_TEST_2  nrmse_RF_TEST_2  R2_RF_TEST_2
# 0  Al2O3        0.379161         0.033868      0.960990
# 1   SiO2        2.315098         0.048845      0.915026
# 2   TiO2        0.030198         0.049525      0.883165
# 3  Fe2O3        0.180964         0.063082      0.885663
# 4    MnO        0.005126         0.131209      0.581244
# 5    MgO        0.258512         0.109229      0.624001
# 6    CaO        2.074609         0.049808      0.926393
# 7   Na2O        0.321981         0.094937      0.711988
# 8    K2O        0.160331         0.052449      0.882540
# 9   P2O5        0.076780         0.119539      0.490440
#
#
# C1 TEST_2 scores
#    y_hat  rmse_RF_TEST_2  nrmse_RF_TEST_2  R2_RF_TEST_2
# 0  Al2O3        0.892841         0.056905      0.891879
# 1   SiO2        4.771733         0.090925      0.849071
# 2   TiO2        0.052290         0.104579      0.784513
# 3  Fe2O3        0.867930         0.116814      0.322210
# 4    MnO        0.031491         0.174951      0.006501
# 5    MgO        2.074706         0.144177      0.023269
# 6    CaO        4.168679         0.099018      0.820655
# 7   Na2O        0.428066         0.212968      0.056871
# 8    K2O        0.164127         0.053812      0.910075
# 9   P2O5        0.194866         0.144345      0.223559

# %%
Random_Forest('TEST_3', 'C1_TEST_3')
# Out:
# Final model best hyperparameters:
#
# {'max_depth': 10, 'max_features': 5, 'n_estimators': 150} : -0.36368175032751215 neg_root_mean_squared_error
#
# Wells Test Scores
# Al2O3:
# RMSE: 0.29852101160143213
# NRMSE: 0.02073627067933994
# R2 score: 0.9812247811901312
#
#
# C1 Prediction Scores
# Al2O3:
# RMSE: 0.8209694734254923
# NRMSE: 0.05232437689136345
# R2 score: 0.90858556456075
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 10, 'max_features': 10, 'n_estimators': 150} : -2.0089189472106415 neg_root_mean_squared_error
#
# Wells Test Scores
# SiO2:
# RMSE: 1.6877705691316929
# NRMSE: 0.033659481859334754
# R2 score: 0.957045363178637
#
#
# C1 Prediction Scores
# SiO2:
# RMSE: 4.740461805661689
# NRMSE: 0.09032892160178523
# R2 score: 0.8510426562712772
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': None, 'max_features': 5, 'n_estimators': 150} : -0.032375128546626865 neg_root_mean_squared_error
#
# Wells Test Scores
# TiO2:
# RMSE: 0.025656333956393624
# NRMSE: 0.04081893587742009
# R2 score: 0.9329840219249219
#
#
# C1 Prediction Scores
# TiO2:
# RMSE: 0.061516971857518435
# NRMSE: 0.12303394371503687
# R2 score: 0.7017494538213719
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 10, 'max_features': 25, 'n_estimators': 30} : -0.16023910599592564 neg_root_mean_squared_error
#
# Wells Test Scores
# Fe2O3:
# RMSE: 0.16247474804315512
# NRMSE: 0.04679545280359996
# R2 score: 0.9110942992519955
#
#
# C1 Prediction Scores
# Fe2O3:
# RMSE: 0.8668609833860219
# NRMSE: 0.11667038807348883
# R2 score: 0.323878198982367
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 20, 'max_features': 5, 'n_estimators': 70} : -0.008650321185887346 neg_root_mean_squared_error
#
# Wells Test Scores
# MnO:
# RMSE: 0.005298100907692308
# NRMSE: 0.07234877656277904
# R2 score: 0.7499372340848454
#
#
# C1 Prediction Scores
# MnO:
# RMSE: 0.02677671655646159
# NRMSE: 0.14875953642478662
# R2 score: 0.2817058078730288
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 20, 'max_features': 5, 'n_estimators': 150} : -0.34305273277535925 neg_root_mean_squared_error
#
# Wells Test Scores
# MgO:
# RMSE: 0.31897041490236955
# NRMSE: 0.142998867963655
# R2 score: 0.5535199026964213
#
#
# C1 Prediction Scores
# MgO:
# RMSE: 1.8514730052663488
# NRMSE: 0.12866386416027442
# R2 score: 0.22214875401631806
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 20, 'max_features': 25, 'n_estimators': 30} : -1.780013908644731 neg_root_mean_squared_error
#
# Wells Test Scores
# CaO:
# RMSE: 1.6243863215806227
# NRMSE: 0.041215118433077076
# R2 score: 0.9523359963016851
#
#
# C1 Prediction Scores
# CaO:
# RMSE: 4.364406616644649
# NRMSE: 0.10366761559726007
# R2 score: 0.8034179414000863
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 20, 'max_features': 5, 'n_estimators': 150} : -0.2693553320806666 neg_root_mean_squared_error
#
# Wells Test Scores
# Na2O:
# RMSE: 0.2748913148382707
# NRMSE: 0.08372281810902604
# R2 score: 0.750875619911344
#
#
# C1 Prediction Scores
# Na2O:
# RMSE: 0.33845009742216203
# NRMSE: 0.16838313304585178
# R2 score: 0.41042576581717827
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 10, 'max_features': 10, 'n_estimators': 150} : -0.14973501102957604 neg_root_mean_squared_error
#
# Wells Test Scores
# K2O:
# RMSE: 0.11163582127716129
# NRMSE: 0.026650072518688762
# R2 score: 0.9624404964582
#
#
# C1 Prediction Scores
# K2O:
# RMSE: 0.18014547184929094
# NRMSE: 0.05906408913091507
# R2 score: 0.8916647266835454
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': None, 'max_features': 5, 'n_estimators': 150} : -0.07955185930550547 neg_root_mean_squared_error
#
# Wells Test Scores
# P2O5:
# RMSE: 0.07235689356543777
# NRMSE: 0.10404177604094811
# R2 score: 0.44671913980666456
#
#
# C1 Prediction Scores
# P2O5:
# RMSE: 0.19117685374137164
# NRMSE: 0.1416124842528679
# R2 score: 0.252681023830334
#
#
#
# Well TEST_3 validation
#    y_hat  rmse_RF_TEST_3  nrmse_RF_TEST_3  R2_RF_TEST_3
# 0  Al2O3        0.298521         0.020736      0.981225
# 1   SiO2        1.687771         0.033659      0.957045
# 2   TiO2        0.025656         0.040819      0.932984
# 3  Fe2O3        0.162475         0.046795      0.911094
# 4    MnO        0.005298         0.072349      0.749937
# 5    MgO        0.318970         0.142999      0.553520
# 6    CaO        1.624386         0.041215      0.952336
# 7   Na2O        0.274891         0.083723      0.750876
# 8    K2O        0.111636         0.026650      0.962440
# 9   P2O5        0.072357         0.104042      0.446719
#
#
# C1 TEST_3 scores
#    y_hat  rmse_RF_TEST_3  nrmse_RF_TEST_3  R2_RF_TEST_3
# 0  Al2O3        0.820969         0.052324      0.908586
# 1   SiO2        4.740462         0.090329      0.851043
# 2   TiO2        0.061517         0.123034      0.701749
# 3  Fe2O3        0.866861         0.116670      0.323878
# 4    MnO        0.026777         0.148760      0.281706
# 5    MgO        1.851473         0.128664      0.222149
# 6    CaO        4.364407         0.103668      0.803418
# 7   Na2O        0.338450         0.168383      0.410426
# 8    K2O        0.180145         0.059064      0.891665
# 9   P2O5        0.191177         0.141612      0.252681

# %%
Random_Forest('TEST_4', 'C1_TEST_4')
# Out:
# Final model best hyperparameters:
#
# {'max_depth': None, 'max_features': 10, 'n_estimators': 150} : -0.33906016074429596 neg_root_mean_squared_error
#
# Wells Test Scores
# Al2O3:
# RMSE: 0.34843120499654257
# NRMSE: 0.024203200107011255
# R2 score: 0.9733690984929319
#
#
# C1 Prediction Scores
# Al2O3:
# RMSE: 0.7665577008593539
# NRMSE: 0.04885645002290338
# R2 score: 0.9203014416258785
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 10, 'max_features': 10, 'n_estimators': 70} : -1.9613449421152533 neg_root_mean_squared_error
#
# Wells Test Scores
# SiO2:
# RMSE: 2.0239502882835505
# NRMSE: 0.04036396845557263
# R2 score: 0.9341769277332768
#
#
# C1 Prediction Scores
# SiO2:
# RMSE: 5.254016373879652
# NRMSE: 0.10011464127057262
# R2 score: 0.8170200690179052
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 10, 'max_features': 5, 'n_estimators': 150} : -0.02518417723989991 neg_root_mean_squared_error
#
# Wells Test Scores
# TiO2:
# RMSE: 0.035053982018028854
# NRMSE: 0.05801238232193438
# R2 score: 0.8406632767696682
#
#
# C1 Prediction Scores
# TiO2:
# RMSE: 0.06395531582798482
# NRMSE: 0.12791063165596964
# R2 score: 0.6776374038190418
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': None, 'max_features': 5, 'n_estimators': 150} : -0.13783278529474208 neg_root_mean_squared_error
#
# Wells Test Scores
# Fe2O3:
# RMSE: 0.20740281285536355
# NRMSE: 0.059735489097229734
# R2 score: 0.8707668449019461
#
#
# C1 Prediction Scores
# Fe2O3:
# RMSE: 0.8627735302572708
# NRMSE: 0.11612025979236484
# R2 score: 0.33023931264227746
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': None, 'max_features': 10, 'n_estimators': 70} : -0.005175426377211091 neg_root_mean_squared_error
#
# Wells Test Scores
# MnO:
# RMSE: 0.00439762964967159
# NRMSE: 0.09922449570558642
# R2 score: 0.7092759968079967
#
#
# C1 Prediction Scores
# MnO:
# RMSE: 0.028691151581045106
# NRMSE: 0.1593952865613617
# R2 score: 0.1753233995992164
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': None, 'max_features': 10, 'n_estimators': 150} : -0.304781277873268 neg_root_mean_squared_error
#
# Wells Test Scores
# MgO:
# RMSE: 0.3915088148874904
# NRMSE: 0.11731444804644842
# R2 score: 0.3611942021673109
#
#
# C1 Prediction Scores
# MgO:
# RMSE: 1.9056812041020228
# NRMSE: 0.13243093843655476
# R2 score: 0.17593345354156165
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': None, 'max_features': 5, 'n_estimators': 150} : -1.732842248842815 neg_root_mean_squared_error
#
# Wells Test Scores
# CaO:
# RMSE: 2.4699833174264776
# NRMSE: 0.06267022419666703
# R2 score: 0.8848408052253584
#
#
# C1 Prediction Scores
# CaO:
# RMSE: 5.350015404661053
# NRMSE: 0.12707875070453808
# R2 score: 0.7046047328832724
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': None, 'max_features': 10, 'n_estimators': 150} : -0.22415911167641905 neg_root_mean_squared_error
#
# Wells Test Scores
# Na2O:
# RMSE: 0.2948503408305518
# NRMSE: 0.08693726454743192
# R2 score: 0.7352351783125133
#
#
# C1 Prediction Scores
# Na2O:
# RMSE: 0.40503345662640944
# NRMSE: 0.20150918240119875
# R2 score: 0.15563347883853274
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 10, 'max_features': 5, 'n_estimators': 150} : -0.1405749399322106 neg_root_mean_squared_error
#
# Wells Test Scores
# K2O:
# RMSE: 0.14280827433041343
# NRMSE: 0.03409166362224744
# R2 score: 0.9391611511814917
#
#
# C1 Prediction Scores
# K2O:
# RMSE: 0.2679393383559487
# NRMSE: 0.08784896339539301
# R2 score: 0.7603396748137571
#
#
#
# Final model best hyperparameters:
#
# {'max_depth': 20, 'max_features': 5, 'n_estimators': 150} : -0.07752325340105921 neg_root_mean_squared_error
#
# Wells Test Scores
# P2O5:
# RMSE: 0.06429682004650503
# NRMSE: 0.10266629416466544
# R2 score: 0.5288582521915526
#
#
# C1 Prediction Scores
# P2O5:
# RMSE: 0.19083490100977057
# NRMSE: 0.1413591859331634
# R2 score: 0.25535205031376795
#
#
#
# Well TEST_4 validation
#    y_hat  rmse_RF_TEST_4  nrmse_RF_TEST_4  R2_RF_TEST_4
# 0  Al2O3        0.348431         0.024203      0.973369
# 1   SiO2        2.023950         0.040364      0.934177
# 2   TiO2        0.035054         0.058012      0.840663
# 3  Fe2O3        0.207403         0.059735      0.870767
# 4    MnO        0.004398         0.099224      0.709276
# 5    MgO        0.391509         0.117314      0.361194
# 6    CaO        2.469983         0.062670      0.884841
# 7   Na2O        0.294850         0.086937      0.735235
# 8    K2O        0.142808         0.034092      0.939161
# 9   P2O5        0.064297         0.102666      0.528858
#
#
# C1 TEST_4 scores
#    y_hat  rmse_RF_TEST_4  nrmse_RF_TEST_4  R2_RF_TEST_4
# 0  Al2O3        0.766558         0.048856      0.920301
# 1   SiO2        5.254016         0.100115      0.817020
# 2   TiO2        0.063955         0.127911      0.677637
# 3  Fe2O3        0.862774         0.116120      0.330239
# 4    MnO        0.028691         0.159395      0.175323
# 5    MgO        1.905681         0.132431      0.175933
# 6    CaO        5.350015         0.127079      0.704605
# 7   Na2O        0.405033         0.201509      0.155633
# 8    K2O        0.267939         0.087849      0.760340
# 9   P2O5        0.190835         0.141359      0.255352

# %% [markdown]
# ## Histogram-based Gradient Boosting Regression Tree

# %%
def HGBT(test, C1_test):
    
    wells_scores = pd.DataFrame()
    C1_scores = pd.DataFrame()
    pred = pd.DataFrame(C1_depth)
        
    for col in Tests[test].iloc[:,1:-1]:
        X = Tests[test].drop([col], axis=1)
        y = Tests[test][col]
        
                
        X_train, X_test, y_train, y_test = train_test_split(
                                            X,
                                            y,
                                            train_size   = 0.7,
                                            random_state = 123,
                                            shuffle      = True
                                        ) 


        # Evaluated Hyperparameters
    
        param_grid = {'loss'             : ['squared_error', 'absolute_error'],
                      'learning_rate'    : [0.001, 0.01, 0.1],
                      'max_depth'        : [3, 5, 10, 20],
                      'l2_regularization': [0, 1, 10]
                     }

        # Grid
        
        grid = GridSearchCV(
                estimator  = HistGradientBoostingRegressor(
                                max_iter            = 1000, 
                                random_state        = 123,
                                early_stopping      = True,
                                validation_fraction = 0.1,
                                n_iter_no_change    = 10,
                                tol                 = 1e-7,
                                scoring             = 'loss',
                            ),
                param_grid = param_grid,
                scoring    = 'neg_root_mean_squared_error',
                n_jobs     = multiprocessing.cpu_count() - 1,
                cv         = RepeatedKFold(n_splits=3, n_repeats=1, random_state=123), 
                refit      = True,
                verbose    = 0,
                return_train_score = True
               )

        grid.fit(X = X_train, y = y_train)
        
        
        print("Final model best hyperparameters: ")        
        print("")       
        print(grid.best_params_, ":", grid.best_score_, grid.scoring)
        print("")        
        print(f"Final trees early stopping: {grid.best_estimator_.n_iter_}")
        print("")    
        
        
        # Test scores
    
        final_model = grid.best_estimator_
        predictions = final_model.predict(X = X_test)
        rmse = mean_squared_error(
                y_true  = y_test,
                y_pred  = predictions,
                squared = False
           )
        
        nrmse = rmse/(y_test.max()-y_test.min())
        
        R2 = r2_score(y_test, predictions)        
        
        print("Wells Test Scores")
        print(f"{col}:")
        print(f"RMSE: {rmse}")
        print(f"NRMSE: {nrmse}")        
        print(f"R2 score: {R2}")
        print("")
        print("")
        
                  
        # Save well test validation
        
        wells_scores = wells_scores.append({"y_hat":col,f"rmse_HGBT_{test}": rmse, f"nrmse_HGBT_{test}": nrmse,
                                           f"R2_HGBT_{test}": R2},ignore_index=True)
                
        wells_scores.to_excel(f"Wells_Mayor_scores_HGBT_{test}.xlsx")  
    
           
        # WELL C1 MAYOR ELEMENTS PREDICTIONS 
                
        X_test_C1 = Tests[C1_test].drop([col], axis=1)
        y_test_C1 = Tests[C1_test][col]
        
        C1_predictions = final_model.predict(X_test_C1) 
    
        rmse_C1 = mean_squared_error(
                    y_true  = y_test_C1,
                    y_pred  = C1_predictions,
                    squared = False
                   )
                
        nrmse_C1 = rmse_C1/(y_test_C1.max()-y_test_C1.min())
        
        R2_C1 = r2_score(y_test_C1, C1_predictions) 
                
        
        print("C1 Prediction Scores")
        print(f"{col}:")
        print(f"RMSE: {rmse_C1}")
        print(f"NRMSE: {nrmse_C1}")        
        print(f"R2 score: {R2_C1}")
        print("")
        print("")   
    
        # Save C1 predicted curves
        
        C1_pred = pd.DataFrame()

        C1_pred = C1_pred.assign(Predictions = C1_predictions.flatten().tolist())        
                
        pred = pd.concat([pred,C1_pred],axis=1)
        
        pred.columns = pred.columns.str.replace('Predictions', f"{col}")
        
        pred.to_excel(f"C1_Mayor_pred_HGBT_{test}.xlsx")  
        
        
        # Save C1 predictions scores
    
        C1_scores = C1_scores.append({'y_hat':col,f"rmse_HGBT_{test}": rmse_C1, f"nrmse_HGBT_{test}": nrmse_C1,
                                 f"R2_HGBT_{test}": R2_C1}, ignore_index=True)
        
        C1_scores.to_excel(f"C1_Mayor_scores_HGBT_{test}.xlsx")         
                
    
        print("")
        
    print(f"Well {test} validation")
    print(wells_scores)
    print("")
    print("")
    print(f"C1 {test} scores")
    print(C1_scores)

# %%
HGBT('TEST_1', 'C1_TEST_1')
# Out:
# Final model best hyperparameters:
#
# {'l2_regularization': 10, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 3} : -0.5851221361984279 neg_root_mean_squared_error
#
# Final trees early stopping: 36
#
# Wells Test Scores
# Al2O3:
# RMSE: 0.49564725278164157
# NRMSE: 0.03843671867187599
# R2 score: 0.9408662570320647
#
#
# C1 Prediction Scores
# Al2O3:
# RMSE: 1.0037909521323576
# NRMSE: 0.06397647878472643
# R2 score: 0.8633381431077904
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 0, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 5} : -2.8235475924983917 neg_root_mean_squared_error
#
# Final trees early stopping: 47
#
# Wells Test Scores
# SiO2:
# RMSE: 1.6234442468949428
# NRMSE: 0.03384243428109182
# R2 score: 0.9577774411668333
#
#
# C1 Prediction Scores
# SiO2:
# RMSE: 5.289295751514374
# NRMSE: 0.10078688550903914
# R2 score: 0.8145544918801993
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 1, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 10} : -0.04345309164510813 neg_root_mean_squared_error
#
# Final trees early stopping: 39
#
# Wells Test Scores
# TiO2:
# RMSE: 0.031130847164444548
# NRMSE: 0.045459101304660486
# R2 score: 0.9125940121810256
#
#
# C1 Prediction Scores
# TiO2:
# RMSE: 0.07861768988058429
# NRMSE: 0.15723537976116858
# R2 score: 0.5128845489202388
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 1, 'learning_rate': 0.01, 'loss': 'squared_error', 'max_depth': 3} : -0.16953852037895503 neg_root_mean_squared_error
#
# Final trees early stopping: 396
#
# Wells Test Scores
# Fe2O3:
# RMSE: 0.16779200411004738
# NRMSE: 0.06742588188658707
# R2 score: 0.8876541004270219
#
#
# C1 Prediction Scores
# Fe2O3:
# RMSE: 0.8623526372693855
# NRMSE: 0.11606361201472214
# R2 score: 0.330892621551116
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 1, 'learning_rate': 0.1, 'loss': 'absolute_error', 'max_depth': 10} : -0.009378556294420094 neg_root_mean_squared_error
#
# Final trees early stopping: 53
#
# Wells Test Scores
# MnO:
# RMSE: 0.004458092257925171
# NRMSE: 0.07633719619734883
# R2 score: 0.7688200043536828
#
#
# C1 Prediction Scores
# MnO:
# RMSE: 0.03069378142889111
# NRMSE: 0.17052100793828395
# R2 score: 0.056181459536186806
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 10, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 5} : -0.37776796582812744 neg_root_mean_squared_error
#
# Final trees early stopping: 64
#
# Wells Test Scores
# MgO:
# RMSE: 0.26059031112273406
# NRMSE: 0.11528963333469038
# R2 score: 0.6209906229873017
#
#
# C1 Prediction Scores
# MgO:
# RMSE: 1.970253605859027
# NRMSE: 0.13691824919103732
# R2 score: 0.11914171194013878
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 0, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 10} : -2.080204569622188 neg_root_mean_squared_error
#
# Final trees early stopping: 42
#
# Wells Test Scores
# CaO:
# RMSE: 1.497101994706703
# NRMSE: 0.037985567348407516
# R2 score: 0.9621067715609096
#
#
# C1 Prediction Scores
# CaO:
# RMSE: 3.4421465613719344
# NRMSE: 0.08176120098270628
# R2 score: 0.8777209140648735
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 1, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 5} : -0.35177522276957734 neg_root_mean_squared_error
#
# Final trees early stopping: 37
#
# Wells Test Scores
# Na2O:
# RMSE: 0.2673384117491743
# NRMSE: 0.07755548547143777
# R2 score: 0.8314452891122261
#
#
# C1 Prediction Scores
# Na2O:
# RMSE: 0.7677677639620172
# NRMSE: 0.3819740119214016
# R2 score: -2.033953748207035
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 10, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 3} : -0.2786658323998533 neg_root_mean_squared_error
#
# Final trees early stopping: 33
#
# Wells Test Scores
# K2O:
# RMSE: 0.16985605743820167
# NRMSE: 0.04932714695050957
# R2 score: 0.8925421030258595
#
#
# C1 Prediction Scores
# K2O:
# RMSE: 0.23238727863568343
# NRMSE: 0.07619255037235523
# R2 score: 0.8197198613406603
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 0, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 3} : -0.08833599448709217 neg_root_mean_squared_error
#
# Final trees early stopping: 28
#
# Wells Test Scores
# P2O5:
# RMSE: 0.06792701126371647
# NRMSE: 0.13433071225051213
# R2 score: 0.48910976313171384
#
#
# C1 Prediction Scores
# P2O5:
# RMSE: 0.22975596321594507
# NRMSE: 0.17018960238218156
# R2 score: -0.07936659824120373
#
#
#
# Well TEST_1 validation
#    y_hat  rmse_HGBT_TEST_1  nrmse_HGBT_TEST_1  R2_HGBT_TEST_1
# 0  Al2O3          0.495647           0.038437        0.940866
# 1   SiO2          1.623444           0.033842        0.957777
# 2   TiO2          0.031131           0.045459        0.912594
# 3  Fe2O3          0.167792           0.067426        0.887654
# 4    MnO          0.004458           0.076337        0.768820
# 5    MgO          0.260590           0.115290        0.620991
# 6    CaO          1.497102           0.037986        0.962107
# 7   Na2O          0.267338           0.077555        0.831445
# 8    K2O          0.169856           0.049327        0.892542
# 9   P2O5          0.067927           0.134331        0.489110
#
#
# C1 TEST_1 scores
#    y_hat  rmse_HGBT_TEST_1  nrmse_HGBT_TEST_1  R2_HGBT_TEST_1
# 0  Al2O3          1.003791           0.063976        0.863338
# 1   SiO2          5.289296           0.100787        0.814554
# 2   TiO2          0.078618           0.157235        0.512885
# 3  Fe2O3          0.862353           0.116064        0.330893
# 4    MnO          0.030694           0.170521        0.056181
# 5    MgO          1.970254           0.136918        0.119142
# 6    CaO          3.442147           0.081761        0.877721
# 7   Na2O          0.767768           0.381974       -2.033954
# 8    K2O          0.232387           0.076193        0.819720
# 9   P2O5          0.229756           0.170190       -0.079367

# %%
HGBT('TEST_2', 'C1_TEST_2')
# Out:
# Final model best hyperparameters:
#
# {'l2_regularization': 0, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 5} : -0.5472089445502716 neg_root_mean_squared_error
#
# Final trees early stopping: 107
#
# Wells Test Scores
# Al2O3:
# RMSE: 0.5363788430063392
# NRMSE: 0.04791188679756958
# R2 score: 0.9219321023115044
#
#
# C1 Prediction Scores
# Al2O3:
# RMSE: 1.046798074833129
# NRMSE: 0.06671753185679599
# R2 score: 0.8513768046065631
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 10, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 10} : -2.283808194905339 neg_root_mean_squared_error
#
# Final trees early stopping: 282
#
# Wells Test Scores
# SiO2:
# RMSE: 2.052602726522527
# NRMSE: 0.04330661418770831
# R2 score: 0.9332027417221245
#
#
# C1 Prediction Scores
# SiO2:
# RMSE: 5.11217077325779
# NRMSE: 0.09741179064896703
# R2 score: 0.8267667226186981
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 10, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 3} : -0.03020623034290389 neg_root_mean_squared_error
#
# Final trees early stopping: 172
#
# Wells Test Scores
# TiO2:
# RMSE: 0.034383987470548535
# NRMSE: 0.05639030335473314
# R2 score: 0.8485249568221224
#
#
# C1 Prediction Scores
# TiO2:
# RMSE: 0.0479401274841875
# NRMSE: 0.095880254968375
# R2 score: 0.8188702790421274
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 10, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 5} : -0.15713701997405516 neg_root_mean_squared_error
#
# Final trees early stopping: 109
#
# Wells Test Scores
# Fe2O3:
# RMSE: 0.17723904003717167
# NRMSE: 0.061783748749319085
# R2 score: 0.8903219037738406
#
#
# C1 Prediction Scores
# Fe2O3:
# RMSE: 0.8927490154470245
# NRMSE: 0.12015464541682698
# R2 score: 0.282891637410167
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 10, 'learning_rate': 0.1, 'loss': 'absolute_error', 'max_depth': 5} : -0.00397547646137211 neg_root_mean_squared_error
#
# Final trees early stopping: 52
#
# Wells Test Scores
# MnO:
# RMSE: 0.005011582366811159
# NRMSE: 0.12827188038933093
# R2 score: 0.599779669744546
#
#
# C1 Prediction Scores
# MnO:
# RMSE: 0.03177401304270399
# NRMSE: 0.17652229468168884
# R2 score: -0.011420730866490425
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 1, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 3} : -0.3517244472067182 neg_root_mean_squared_error
#
# Final trees early stopping: 111
#
# Wells Test Scores
# MgO:
# RMSE: 0.24270528641341843
# NRMSE: 0.10255008510306267
# R2 score: 0.6685767283547979
#
#
# C1 Prediction Scores
# MgO:
# RMSE: 2.037067386789742
# NRMSE: 0.14156131944334552
# R2 score: 0.05838672060478356
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 10, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 10} : -1.9721901463212739 neg_root_mean_squared_error
#
# Final trees early stopping: 287
#
# Wells Test Scores
# CaO:
# RMSE: 2.2067826171972045
# NRMSE: 0.05298093620071272
# R2 score: 0.9167155780753933
#
#
# C1 Prediction Scores
# CaO:
# RMSE: 4.246953283225574
# NRMSE: 0.10087775019538181
# R2 score: 0.8138562601581533
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 1, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 5} : -0.26461856593835986 neg_root_mean_squared_error
#
# Final trees early stopping: 95
#
# Wells Test Scores
# Na2O:
# RMSE: 0.3273404184101888
# NRMSE: 0.09651703461570112
# R2 score: 0.702319953721459
#
#
# C1 Prediction Scores
# Na2O:
# RMSE: 0.3900371914822753
# NRMSE: 0.19404835397128126
# R2 score: 0.2170009235289755
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 0, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 5} : -0.17245900283178614 neg_root_mean_squared_error
#
# Final trees early stopping: 328
#
# Wells Test Scores
# K2O:
# RMSE: 0.18733992014695935
# NRMSE: 0.06128428150968608
# R2 score: 0.839633483271544
#
#
# C1 Prediction Scores
# K2O:
# RMSE: 0.2260979183557898
# NRMSE: 0.07413046503468518
# R2 score: 0.8293460634307064
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 10, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 10} : -0.08096975694716957 neg_root_mean_squared_error
#
# Final trees early stopping: 78
#
# Wells Test Scores
# P2O5:
# RMSE: 0.0831697725631359
# NRMSE: 0.12948742419918402
# R2 score: 0.40209611419443203
#
#
# C1 Prediction Scores
# P2O5:
# RMSE: 0.19657332984425394
# NRMSE: 0.14560987395870664
# R2 score: 0.2098954204999377
#
#
#
# Well TEST_2 validation
#    y_hat  rmse_HGBT_TEST_2  nrmse_HGBT_TEST_2  R2_HGBT_TEST_2
# 0  Al2O3          0.536379           0.047912        0.921932
# 1   SiO2          2.052603           0.043307        0.933203
# 2   TiO2          0.034384           0.056390        0.848525
# 3  Fe2O3          0.177239           0.061784        0.890322
# 4    MnO          0.005012           0.128272        0.599780
# 5    MgO          0.242705           0.102550        0.668577
# 6    CaO          2.206783           0.052981        0.916716
# 7   Na2O          0.327340           0.096517        0.702320
# 8    K2O          0.187340           0.061284        0.839633
# 9   P2O5          0.083170           0.129487        0.402096
#
#
# C1 TEST_2 scores
#    y_hat  rmse_HGBT_TEST_2  nrmse_HGBT_TEST_2  R2_HGBT_TEST_2
# 0  Al2O3          1.046798           0.066718        0.851377
# 1   SiO2          5.112171           0.097412        0.826767
# 2   TiO2          0.047940           0.095880        0.818870
# 3  Fe2O3          0.892749           0.120155        0.282892
# 4    MnO          0.031774           0.176522       -0.011421
# 5    MgO          2.037067           0.141561        0.058387
# 6    CaO          4.246953           0.100878        0.813856
# 7   Na2O          0.390037           0.194048        0.217001
# 8    K2O          0.226098           0.074130        0.829346
# 9   P2O5          0.196573           0.145610        0.209895

# %%
HGBT('TEST_3', 'C1_TEST_3')
# Out:
# Final model best hyperparameters:
#
# {'l2_regularization': 1, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 3} : -0.5688635243004324 neg_root_mean_squared_error
#
# Final trees early stopping: 250
#
# Wells Test Scores
# Al2O3:
# RMSE: 0.33644273893612087
# NRMSE: 0.023370441046182078
# R2 score: 0.9761516949926428
#
#
# C1 Prediction Scores
# Al2O3:
# RMSE: 0.9816968692830123
# NRMSE: 0.06256831544187459
# R2 score: 0.8692879650587503
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 1, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 3} : -2.6230921761604615 neg_root_mean_squared_error
#
# Final trees early stopping: 177
#
# Wells Test Scores
# SiO2:
# RMSE: 1.7214989102080622
# NRMSE: 0.03433213162901854
# R2 score: 0.9553114013048215
#
#
# C1 Prediction Scores
# SiO2:
# RMSE: 5.263421071386581
# NRMSE: 0.10029384663465284
# R2 score: 0.8163644140069741
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 0, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 5} : -0.04262992939110936 neg_root_mean_squared_error
#
# Final trees early stopping: 223
#
# Wells Test Scores
# TiO2:
# RMSE: 0.025310441141930907
# NRMSE: 0.0402686243388343
# R2 score: 0.9347788293403749
#
#
# C1 Prediction Scores
# TiO2:
# RMSE: 0.061091589320877486
# NRMSE: 0.12218317864175497
# R2 score: 0.7058599268376239
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 10, 'learning_rate': 0.01, 'loss': 'squared_error', 'max_depth': 3} : -0.18138295950776648 neg_root_mean_squared_error
#
# Final trees early stopping: 998
#
# Wells Test Scores
# Fe2O3:
# RMSE: 0.1636174824239649
# NRMSE: 0.047124579473610435
# R2 score: 0.909839299585617
#
#
# C1 Prediction Scores
# Fe2O3:
# RMSE: 0.871311223677801
# NRMSE: 0.11726934369822356
# R2 score: 0.316918310354532
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 10, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 3} : -0.008779465497672468 neg_root_mean_squared_error
#
# Final trees early stopping: 23
#
# Wells Test Scores
# MnO:
# RMSE: 0.006143477445552916
# NRMSE: 0.08389290516936934
# R2 score: 0.6637694928202089
#
#
# C1 Prediction Scores
# MnO:
# RMSE: 0.030027359053621312
# NRMSE: 0.1668186614090073
# R2 score: 0.09672084885639887
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 0, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 5} : -0.39121612566520736 neg_root_mean_squared_error
#
# Final trees early stopping: 56
#
# Wells Test Scores
# MgO:
# RMSE: 0.28821753240804326
# NRMSE: 0.1292119235391886
# R2 score: 0.6354626024680619
#
#
# C1 Prediction Scores
# MgO:
# RMSE: 1.886055340854194
# NRMSE: 0.13106708414553123
# R2 score: 0.1928195282241918
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 1, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 10} : -2.1107654578467527 neg_root_mean_squared_error
#
# Final trees early stopping: 187
#
# Wells Test Scores
# CaO:
# RMSE: 1.5165670408742338
# NRMSE: 0.03847944874376392
# R2 score: 0.9584534373112987
#
#
# C1 Prediction Scores
# CaO:
# RMSE: 5.141077603904535
# NRMSE: 0.12211585757492958
# R2 score: 0.7272267446529297
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 1, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 10} : -0.31659039901141267 neg_root_mean_squared_error
#
# Final trees early stopping: 129
#
# Wells Test Scores
# Na2O:
# RMSE: 0.2381877978847864
# NRMSE: 0.07254413872562669
# R2 score: 0.8129605518743976
#
#
# C1 Prediction Scores
# Na2O:
# RMSE: 0.3518192039191309
# NRMSE: 0.1750344298105129
# R2 score: 0.3629283315102758
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 10, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 3} : -0.23820120030713046 neg_root_mean_squared_error
#
# Final trees early stopping: 152
#
# Wells Test Scores
# K2O:
# RMSE: 0.13700445525350735
# NRMSE: 0.032706156734624986
# R2 score: 0.9434305338657849
#
#
# C1 Prediction Scores
# K2O:
# RMSE: 0.2537529458125731
# NRMSE: 0.08319768715166333
# R2 score: 0.7850460805580678
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 0, 'learning_rate': 0.1, 'loss': 'absolute_error', 'max_depth': 5} : -0.0942454847372014 neg_root_mean_squared_error
#
# Final trees early stopping: 133
#
# Wells Test Scores
# P2O5:
# RMSE: 0.07292797867602056
# NRMSE: 0.1048629377333284
# R2 score: 0.43795100833467604
#
#
# C1 Prediction Scores
# P2O5:
# RMSE: 0.1980440992690283
# NRMSE: 0.14669933279187283
# R2 score: 0.19802800232618656
#
#
#
# Well TEST_3 validation
#    y_hat  rmse_HGBT_TEST_3  nrmse_HGBT_TEST_3  R2_HGBT_TEST_3
# 0  Al2O3          0.336443           0.023370        0.976152
# 1   SiO2          1.721499           0.034332        0.955311
# 2   TiO2          0.025310           0.040269        0.934779
# 3  Fe2O3          0.163617           0.047125        0.909839
# 4    MnO          0.006143           0.083893        0.663769
# 5    MgO          0.288218           0.129212        0.635463
# 6    CaO          1.516567           0.038479        0.958453
# 7   Na2O          0.238188           0.072544        0.812961
# 8    K2O          0.137004           0.032706        0.943431
# 9   P2O5          0.072928           0.104863        0.437951
#
#
# C1 TEST_3 scores
#    y_hat  rmse_HGBT_TEST_3  nrmse_HGBT_TEST_3  R2_HGBT_TEST_3
# 0  Al2O3          0.981697           0.062568        0.869288
# 1   SiO2          5.263421           0.100294        0.816364
# 2   TiO2          0.061092           0.122183        0.705860
# 3  Fe2O3          0.871311           0.117269        0.316918
# 4    MnO          0.030027           0.166819        0.096721
# 5    MgO          1.886055           0.131067        0.192820
# 6    CaO          5.141078           0.122116        0.727227
# 7   Na2O          0.351819           0.175034        0.362928
# 8    K2O          0.253753           0.083198        0.785046
# 9   P2O5          0.198044           0.146699        0.198028

# %%
HGBT('TEST_4', 'C1_TEST_4')
# Out:
# Final model best hyperparameters:
#
# {'l2_regularization': 0, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 5} : -0.6125556653275294 neg_root_mean_squared_error
#
# Final trees early stopping: 185
#
# Wells Test Scores
# Al2O3:
# RMSE: 0.4981547636017201
# NRMSE: 0.034603500647517944
# R2 score: 0.945564732944087
#
#
# C1 Prediction Scores
# Al2O3:
# RMSE: 1.1629414713791526
# NRMSE: 0.07411991532053236
# R2 score: 0.8165674176765976
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 0, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 5} : -2.4574603841317937 neg_root_mean_squared_error
#
# Final trees early stopping: 276
#
# Wells Test Scores
# SiO2:
# RMSE: 2.225658021997889
# NRMSE: 0.04438665846333727
# R2 score: 0.920403249952868
#
#
# C1 Prediction Scores
# SiO2:
# RMSE: 5.607740657057741
# NRMSE: 0.10685481434942341
# R2 score: 0.7915526124300882
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 0, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 10} : -0.029727896080532095 neg_root_mean_squared_error
#
# Final trees early stopping: 116
#
# Wells Test Scores
# TiO2:
# RMSE: 0.03407948730234279
# NRMSE: 0.0563996479972574
# R2 score: 0.8493992038965932
#
#
# C1 Prediction Scores
# TiO2:
# RMSE: 0.06417993050182345
# NRMSE: 0.1283598610036469
# R2 score: 0.6753691164111514
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 0, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 10} : -0.17754040781507296 neg_root_mean_squared_error
#
# Final trees early stopping: 135
#
# Wells Test Scores
# Fe2O3:
# RMSE: 0.1925702422223583
# NRMSE: 0.0554634599519468
# R2 score: 0.8885902970089218
#
#
# C1 Prediction Scores
# Fe2O3:
# RMSE: 0.8670866137537878
# NRMSE: 0.11670075555232676
# R2 score: 0.32352618529804444
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 0, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 3} : -0.005516107674033006 neg_root_mean_squared_error
#
# Final trees early stopping: 41
#
# Wells Test Scores
# MnO:
# RMSE: 0.004151595729912567
# NRMSE: 0.09367318885181786
# R2 score: 0.7408962496343827
#
#
# C1 Prediction Scores
# MnO:
# RMSE: 0.030487964166690487
# NRMSE: 0.16937757870383605
# R2 score: 0.06879657915026993
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 1, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 5} : -0.3493634549052693 neg_root_mean_squared_error
#
# Final trees early stopping: 41
#
# Wells Test Scores
# MgO:
# RMSE: 0.3791072202378799
# NRMSE: 0.11359834721834078
# R2 score: 0.4010233792579725
#
#
# C1 Prediction Scores
# MgO:
# RMSE: 1.989170712744362
# NRMSE: 0.1382328500864741
# R2 score: 0.10214564054060449
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 0, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 3} : -2.1280198463623923 neg_root_mean_squared_error
#
# Final trees early stopping: 135
#
# Wells Test Scores
# CaO:
# RMSE: 2.324795978467243
# NRMSE: 0.0589864247884293
# R2 score: 0.8979811858837768
#
#
# C1 Prediction Scores
# CaO:
# RMSE: 5.5576363165929195
# NRMSE: 0.13201036381455866
# R2 score: 0.6812327357443664
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 1, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 10} : -0.236532520707472 neg_root_mean_squared_error
#
# Final trees early stopping: 112
#
# Wells Test Scores
# Na2O:
# RMSE: 0.308273346763949
# NRMSE: 0.09089506705349769
# R2 score: 0.7105797142570159
#
#
# C1 Prediction Scores
# Na2O:
# RMSE: 0.3627704289521819
# NRMSE: 0.18048280047372237
# R2 score: 0.3226502642184489
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 0, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 10} : -0.2091985409618767 neg_root_mean_squared_error
#
# Final trees early stopping: 158
#
# Wells Test Scores
# K2O:
# RMSE: 0.21702283518369245
# NRMSE: 0.05180840907236717
# R2 score: 0.8594971573644461
#
#
# C1 Prediction Scores
# K2O:
# RMSE: 0.3945665830533121
# NRMSE: 0.12936609280436462
# R2 score: 0.48028675531832776
#
#
#
# Final model best hyperparameters:
#
# {'l2_regularization': 0, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 3} : -0.08399267765147093 neg_root_mean_squared_error
#
# Final trees early stopping: 53
#
# Wells Test Scores
# P2O5:
# RMSE: 0.07482831330138764
# NRMSE: 0.11948251281617776
# R2 score: 0.3618768331321621
#
#
# C1 Prediction Scores
# P2O5:
# RMSE: 0.20791043836528766
# NRMSE: 0.15400773212243532
# R2 score: 0.11613084491972869
#
#
#
# Well TEST_4 validation
#    y_hat  rmse_HGBT_TEST_4  nrmse_HGBT_TEST_4  R2_HGBT_TEST_4
# 0  Al2O3          0.498155           0.034604        0.945565
# 1   SiO2          2.225658           0.044387        0.920403
# 2   TiO2          0.034079           0.056400        0.849399
# 3  Fe2O3          0.192570           0.055463        0.888590
# 4    MnO          0.004152           0.093673        0.740896
# 5    MgO          0.379107           0.113598        0.401023
# 6    CaO          2.324796           0.058986        0.897981
# 7   Na2O          0.308273           0.090895        0.710580
# 8    K2O          0.217023           0.051808        0.859497
# 9   P2O5          0.074828           0.119483        0.361877
#
#
# C1 TEST_4 scores
#    y_hat  rmse_HGBT_TEST_4  nrmse_HGBT_TEST_4  R2_HGBT_TEST_4
# 0  Al2O3          1.162941           0.074120        0.816567
# 1   SiO2          5.607741           0.106855        0.791553
# 2   TiO2          0.064180           0.128360        0.675369
# 3  Fe2O3          0.867087           0.116701        0.323526
# 4    MnO          0.030488           0.169378        0.068797
# 5    MgO          1.989171           0.138233        0.102146
# 6    CaO          5.557636           0.132010        0.681233
# 7   Na2O          0.362770           0.180483        0.322650
# 8    K2O          0.394567           0.129366        0.480287
# 9   P2O5          0.207910           0.154008        0.116131

# %% [markdown]
# # XGBoost

# %%
def XGB(test, C1_test):
    
    wells_scores = pd.DataFrame()
    C1_scores = pd.DataFrame()
    pred = pd.DataFrame(C1_depth)
        
    for col in Tests[test].iloc[:,1:-1]:
        X = Tests[test].drop([col], axis=1)
        y = Tests[test][col]
        
                
        X_train, X_test, y_train, y_test = train_test_split(
                                            X,
                                            y,
                                            train_size   = 0.7,
                                            random_state = 123,
                                            shuffle      = True
                                        )        
    
        # Evaluated Hyperparameters    
    
        param_grid = {'max_depth'        : [None, 1, 3, 5, 10, 20],
                      'subsample'        : [0.5, 1],
                      'learning_rate'    : [0.001, 0.01, 0.1],
                      'booster'          : ['gbtree']
                 }


        # Creation of validation set
    
        np.random.seed(123)
        idx_validacion = np.random.choice(
                            X_train.shape[0],
                            size=int(X_train.shape[0]*0.1), 
                            replace=False
                         )

        X_val = X_train.iloc[idx_validacion, :].copy()
        y_val = y_train.iloc[idx_validacion].copy()

        X_train_grid = X_train.reset_index(drop = True).drop(idx_validacion, axis = 0).copy()
        y_train_grid = y_train.reset_index(drop = True).drop(idx_validacion, axis = 0).copy()

        
        fit_params = {"eval_set": [(X_val, y_val)],
                       "verbose": False
                     }

        # Grid
    
        grid = GridSearchCV(
                estimator  = XGBRegressor(
                                n_estimators          = 1000,
                                early_stopping_rounds = 5,
                                eval_metric           = "rmse",
                                random_state          = 123
                            ),
                param_grid = param_grid,
                scoring    = 'neg_root_mean_squared_error',
                n_jobs     = multiprocessing.cpu_count() - 1,
                cv         = RepeatedKFold(n_splits=3, n_repeats=1, random_state=123), 
                refit      = True,
                verbose    = 0,
                return_train_score = True
               )

        grid.fit(X = X_train_grid, y = y_train_grid, **fit_params)

        print("Final model best hyperparameters: ")        
        print("")       
        print(grid.best_params_, ":", grid.best_score_, grid.scoring)
        print("")
        n_trees_incluid = len(grid.best_estimator_.get_booster().get_dump())
        print(f"Final trees early stopping: {n_trees_incluid}")
        print("")
    
        # Test scores       
    
        final_model = grid.best_estimator_
        predictions = final_model.predict(X_test)
        
        rmse = mean_squared_error(
                y_true  = y_test,
                y_pred  = predictions,
                squared = False
               )
                
        nrmse = rmse/(y_test.max()-y_test.min())
        
        R2 = r2_score(y_test, predictions)        
        
        print("Wells Test Scores")
        print(f"{col}:")
        print(f"RMSE: {rmse}")
        print(f"NRMSE: {nrmse}")        
        print(f"R2 score: {R2}")
        print("")
        print("")
    
        # Save well test validation
                
        wells_scores= wells_scores.append({"y_hat":col,f"rmse_XGB_{test}": rmse, f"nrmse_XGB_{test}": nrmse,
                                           f"R2_XGB_{test}": R2}, ignore_index=True)
                
        wells_scores.to_excel(f"Wells_Mayor_scores_XGB_{test}.xlsx") 
        
    
        # WELL C1 MAYOR ELEMENTS PREDICTIONS 
                
        X_test_C1 = Tests[C1_test].drop([col], axis=1)
        y_test_C1 = Tests[C1_test][col]
    
        C1_predictions = final_model.predict(X_test_C1) 
    
        rmse_C1 = mean_squared_error(
                    y_true  = y_test_C1,
                    y_pred  = C1_predictions,
                    squared = False
                   )
                
        nrmse_C1 = rmse_C1/(y_test_C1.max()-y_test_C1.min())
        
        R2_C1 = r2_score(y_test_C1, C1_predictions) 
                
        
        print("C1 Prediction Scores")
        print(f"{col}:")
        print(f"RMSE: {rmse_C1}")
        print(f"NRMSE: {nrmse_C1}")        
        print(f"R2 score: {R2_C1}")
        print("")
        print("")
        
        # Save C1 predicted curves
        
        C1_pred = pd.DataFrame()

        C1_pred = C1_pred.assign(Predictions = C1_predictions.flatten().tolist())        
                
        pred = pd.concat([pred,C1_pred],axis=1)
        
        pred.columns = pred.columns.str.replace('Predictions', f"{col}")
        
        pred.to_excel(f"C1_Mayor_pred_XGB_{test}.xlsx")  
        
        
        # Save C1 predictions scores
    
        C1_scores = C1_scores.append({'y_hat':col,f"rmse_XGB_{test}": rmse_C1, f"nrmse_XGB_{test}": nrmse_C1,
                                 f"R2_XGB_{test}": R2_C1}, ignore_index=True)
        
        C1_scores.to_excel(f"C1_Mayor_scores_XGB_{test}.xlsx")
        
        
        print("")
                
    print(f"Well {test} validation")
    print(wells_scores)
    print("")
    print("")
    print(f"C1 {test} scores")
    print(C1_scores)

# %%
XGB('TEST_1', 'C1_TEST_1')
# Out:
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.01, 'max_depth': 3, 'subsample': 0.5} : -0.37103677028311016 neg_root_mean_squared_error
#
# Final trees early stopping: 589
#
# Wells Test Scores
# Al2O3:
# RMSE: 0.2671491744016307
# NRMSE: 0.020717027285578744
# R2 score: 0.9828210096675655
#
#
# C1 Prediction Scores
# Al2O3:
# RMSE: 0.7584099574421082
# NRMSE: 0.048337154712690136
# R2 score: 0.9219866699162895
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': None, 'subsample': 0.5} : -1.978757971434418 neg_root_mean_squared_error
#
# Final trees early stopping: 42
#
# Wells Test Scores
# SiO2:
# RMSE: 1.3725971099731473
# NRMSE: 0.028613257016696814
# R2 score: 0.9698174483241756
#
#
# C1 Prediction Scores
# SiO2:
# RMSE: 4.344764174985751
# NRMSE: 0.08278895150506384
# R2 score: 0.8748724234725603
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': None, 'subsample': 0.5} : -0.028578985563532555 neg_root_mean_squared_error
#
# Final trees early stopping: 44
#
# Wells Test Scores
# TiO2:
# RMSE: 0.03076252723106056
# NRMSE: 0.04492125878865753
# R2 score: 0.9146500386007194
#
#
# C1 Prediction Scores
# TiO2:
# RMSE: 0.06327550182252786
# NRMSE: 0.12655100364505573
# R2 score: 0.6844540974368254
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.01, 'max_depth': 20, 'subsample': 0.5} : -0.18101418494251312 neg_root_mean_squared_error
#
# Final trees early stopping: 380
#
# Wells Test Scores
# Fe2O3:
# RMSE: 0.14317381061899462
# NRMSE: 0.05753325669629366
# R2 score: 0.9182021532418356
#
#
# C1 Prediction Scores
# Fe2O3:
# RMSE: 0.8696889939743053
# NRMSE: 0.1170510086102699
# R2 score: 0.3194595007302623
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 10, 'subsample': 0.5} : -0.009709228738615091 neg_root_mean_squared_error
#
# Final trees early stopping: 32
#
# Wells Test Scores
# MnO:
# RMSE: 0.004260852167691383
# NRMSE: 0.07295979739197575
# R2 score: 0.7888237465936367
#
#
# C1 Prediction Scores
# MnO:
# RMSE: 0.02801585741629532
# NRMSE: 0.1556436523127518
# R2 score: 0.2136868314080277
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': None, 'subsample': 1} : -0.36288126658385494 neg_root_mean_squared_error
#
# Final trees early stopping: 29
#
# Wells Test Scores
# MgO:
# RMSE: 0.25838038875088565
# NRMSE: 0.1143119256875763
# R2 score: 0.6273917034097484
#
#
# C1 Prediction Scores
# MgO:
# RMSE: 1.957187626459582
# NRMSE: 0.13601025896174998
# R2 score: 0.13078601358758668
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.01, 'max_depth': 5, 'subsample': 0.5} : -1.427054534123557 neg_root_mean_squared_error
#
# Final trees early stopping: 399
#
# Wells Test Scores
# CaO:
# RMSE: 1.3034396698474713
# NRMSE: 0.03307182512523273
# R2 score: 0.9712762790449498
#
#
# C1 Prediction Scores
# CaO:
# RMSE: 3.2366588156429934
# NRMSE: 0.07688025690363405
# R2 score: 0.8918846618158915
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.01, 'max_depth': None, 'subsample': 0.5} : -0.28511757862136905 neg_root_mean_squared_error
#
# Final trees early stopping: 259
#
# Wells Test Scores
# Na2O:
# RMSE: 0.2549697436529636
# NRMSE: 0.0739673065316425
# R2 score: 0.8466811819918714
#
#
# C1 Prediction Scores
# Na2O:
# RMSE: 0.725252579504616
# NRMSE: 0.36082217885801793
# R2 score: -1.7072463254921262
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 20, 'subsample': 0.5} : -0.1353000239526995 neg_root_mean_squared_error
#
# Final trees early stopping: 73
#
# Wells Test Scores
# K2O:
# RMSE: 0.12203747699363135
# NRMSE: 0.03544036434099172
# R2 score: 0.9445294210045038
#
#
# C1 Prediction Scores
# K2O:
# RMSE: 0.16281461914035034
# NRMSE: 0.053381842341098475
# R2 score: 0.9115067840125121
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 5, 'subsample': 1} : -0.08082150999070657 neg_root_mean_squared_error
#
# Final trees early stopping: 29
#
# Wells Test Scores
# P2O5:
# RMSE: 0.0617706458830057
# NRMSE: 0.12215604224693119
# R2 score: 0.5775192986724981
#
#
# C1 Prediction Scores
# P2O5:
# RMSE: 0.21991314846290955
# NRMSE: 0.1628986284910441
# R2 score: 0.011133230640618885
#
#
#
# Well TEST_1 validation
#    y_hat  rmse_XGB_TEST_1  nrmse_XGB_TEST_1  R2_XGB_TEST_1
# 0  Al2O3         0.267149          0.020717       0.982821
# 1   SiO2         1.372597          0.028613       0.969817
# 2   TiO2         0.030763          0.044921       0.914650
# 3  Fe2O3         0.143174          0.057533       0.918202
# 4    MnO         0.004261          0.072960       0.788824
# 5    MgO         0.258380          0.114312       0.627392
# 6    CaO         1.303440          0.033072       0.971276
# 7   Na2O         0.254970          0.073967       0.846681
# 8    K2O         0.122037          0.035440       0.944529
# 9   P2O5         0.061771          0.122156       0.577519
#
#
# C1 TEST_1 scores
#    y_hat  rmse_XGB_TEST_1  nrmse_XGB_TEST_1  R2_XGB_TEST_1
# 0  Al2O3         0.758410          0.048337       0.921987
# 1   SiO2         4.344764          0.082789       0.874872
# 2   TiO2         0.063276          0.126551       0.684454
# 3  Fe2O3         0.869689          0.117051       0.319460
# 4    MnO         0.028016          0.155644       0.213687
# 5    MgO         1.957188          0.136010       0.130786
# 6    CaO         3.236659          0.076880       0.891885
# 7   Na2O         0.725253          0.360822      -1.707246
# 8    K2O         0.162815          0.053382       0.911507
# 9   P2O5         0.219913          0.162899       0.011133

# %%
XGB('TEST_2', 'C1_TEST_2')
# Out:
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 10, 'subsample': 0.5} : -0.3704100352833357 neg_root_mean_squared_error
#
# Final trees early stopping: 37
#
# Wells Test Scores
# Al2O3:
# RMSE: 0.42825206158258844
# NRMSE: 0.038253492960997115
# R2 score: 0.9502345276418631
#
#
# C1 Prediction Scores
# Al2O3:
# RMSE: 0.8940634578405375
# NRMSE: 0.056983011971990925
# R2 score: 0.891582983120471
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': None, 'subsample': 0.5} : -1.7345445130843633 neg_root_mean_squared_error
#
# Final trees early stopping: 73
#
# Wells Test Scores
# SiO2:
# RMSE: 2.344078175399965
# NRMSE: 0.04945627707503653
# R2 score: 0.9128849847680952
#
#
# C1 Prediction Scores
# SiO2:
# RMSE: 4.590801773102663
# NRMSE: 0.08747716793259647
# R2 score: 0.8602995847451357
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 3, 'subsample': 0.5} : -0.02709090508508721 neg_root_mean_squared_error
#
# Final trees early stopping: 40
#
# Wells Test Scores
# TiO2:
# RMSE: 0.032846204824265125
# NRMSE: 0.05386831459494076
# R2 score: 0.8617710533106692
#
#
# C1 Prediction Scores
# TiO2:
# RMSE: 0.05204209205434734
# NRMSE: 0.10408418410869467
# R2 score: 0.7865476984211227
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.01, 'max_depth': 5, 'subsample': 0.5} : -0.13340372932198155 neg_root_mean_squared_error
#
# Final trees early stopping: 333
#
# Wells Test Scores
# Fe2O3:
# RMSE: 0.17964305077389103
# NRMSE: 0.06262176274057624
# R2 score: 0.8873264523395286
#
#
# C1 Prediction Scores
# Fe2O3:
# RMSE: 0.8808889114725255
# NRMSE: 0.11855839992900746
# R2 score: 0.3018185375464436
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 3, 'subsample': 1} : -0.0038507941837484794 neg_root_mean_squared_error
#
# Final trees early stopping: 37
#
# Wells Test Scores
# MnO:
# RMSE: 0.005065123316524852
# NRMSE: 0.1296422655880433
# R2 score: 0.5911825288253654
#
#
# C1 Prediction Scores
# MnO:
# RMSE: 0.03102447938169951
# NRMSE: 0.1723582187872195
# R2 score: 0.03573430412786971
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 20, 'subsample': 0.5} : -0.31331681198427097 neg_root_mean_squared_error
#
# Final trees early stopping: 23
#
# Wells Test Scores
# MgO:
# RMSE: 0.26867146952052123
# NRMSE: 0.1135215572402591
# R2 score: 0.5938676072287199
#
#
# C1 Prediction Scores
# MgO:
# RMSE: 2.0564056655033913
# NRMSE: 0.1429051887076714
# R2 score: 0.04042402402635459
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.01, 'max_depth': 5, 'subsample': 0.5} : -1.5484487299772318 neg_root_mean_squared_error
#
# Final trees early stopping: 421
#
# Wells Test Scores
# CaO:
# RMSE: 2.102292102688873
# NRMSE: 0.050472304294876535
# R2 score: 0.9244158410899688
#
#
# C1 Prediction Scores
# CaO:
# RMSE: 4.148048989388804
# NRMSE: 0.09852847955792883
# R2 score: 0.8224252461363867
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.01, 'max_depth': 10, 'subsample': 0.5} : -0.25049130677565484 neg_root_mean_squared_error
#
# Final trees early stopping: 284
#
# Wells Test Scores
# Na2O:
# RMSE: 0.34053674435831466
# NRMSE: 0.10040800003488534
# R2 score: 0.6778349549968627
#
#
# C1 Prediction Scores
# Na2O:
# RMSE: 0.3882667731225598
# NRMSE: 0.19316754881719395
# R2 score: 0.22409301545294213
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 10, 'subsample': 0.5} : -0.1139324088894781 neg_root_mean_squared_error
#
# Final trees early stopping: 112
#
# Wells Test Scores
# K2O:
# RMSE: 0.1511587416963435
# NRMSE: 0.04944837636047745
# R2 score: 0.8955954151932488
#
#
# C1 Prediction Scores
# K2O:
# RMSE: 0.16764230987059106
# NRMSE: 0.05496469176084953
# R2 score: 0.9061810743539289
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 3, 'subsample': 0.5} : -0.07816190785827984 neg_root_mean_squared_error
#
# Final trees early stopping: 30
#
# Wells Test Scores
# P2O5:
# RMSE: 0.08351369832262892
# NRMSE: 0.13002288389012753
# R2 score: 0.39714095526381343
#
#
# C1 Prediction Scores
# P2O5:
# RMSE: 0.20131409120377652
# NRMSE: 0.1491215490398345
# R2 score: 0.1713259484722266
#
#
#
# Well TEST_2 validation
#    y_hat  rmse_XGB_TEST_2  nrmse_XGB_TEST_2  R2_XGB_TEST_2
# 0  Al2O3         0.428252          0.038253       0.950235
# 1   SiO2         2.344078          0.049456       0.912885
# 2   TiO2         0.032846          0.053868       0.861771
# 3  Fe2O3         0.179643          0.062622       0.887326
# 4    MnO         0.005065          0.129642       0.591183
# 5    MgO         0.268671          0.113522       0.593868
# 6    CaO         2.102292          0.050472       0.924416
# 7   Na2O         0.340537          0.100408       0.677835
# 8    K2O         0.151159          0.049448       0.895595
# 9   P2O5         0.083514          0.130023       0.397141
#
#
# C1 TEST_2 scores
#    y_hat  rmse_XGB_TEST_2  nrmse_XGB_TEST_2  R2_XGB_TEST_2
# 0  Al2O3         0.894063          0.056983       0.891583
# 1   SiO2         4.590802          0.087477       0.860300
# 2   TiO2         0.052042          0.104084       0.786548
# 3  Fe2O3         0.880889          0.118558       0.301819
# 4    MnO         0.031024          0.172358       0.035734
# 5    MgO         2.056406          0.142905       0.040424
# 6    CaO         4.148049          0.098528       0.822425
# 7   Na2O         0.388267          0.193168       0.224093
# 8    K2O         0.167642          0.054965       0.906181
# 9   P2O5         0.201314          0.149122       0.171326

# %%
XGB('TEST_3', 'C1_TEST_3')
# Out:
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.01, 'max_depth': 10, 'subsample': 0.5} : -0.34286924016406944 neg_root_mean_squared_error
#
# Final trees early stopping: 517
#
# Wells Test Scores
# Al2O3:
# RMSE: 0.27268091889771773
# NRMSE: 0.018941331174716847
# R2 score: 0.9843344843268416
#
#
# C1 Prediction Scores
# Al2O3:
# RMSE: 0.7236761343473521
# NRMSE: 0.04612339925732009
# R2 score: 0.9289687814762118
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.01, 'max_depth': 10, 'subsample': 0.5} : -2.02417182217658 neg_root_mean_squared_error
#
# Final trees early stopping: 541
#
# Wells Test Scores
# SiO2:
# RMSE: 1.6115102953498537
# NRMSE: 0.03213861086602889
# R2 score: 0.9608393942279121
#
#
# C1 Prediction Scores
# SiO2:
# RMSE: 4.734343794512905
# NRMSE: 0.09021234364544407
# R2 score: 0.8514268950451367
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 3, 'subsample': 1} : -0.03351685351957298 neg_root_mean_squared_error
#
# Final trees early stopping: 62
#
# Wells Test Scores
# TiO2:
# RMSE: 0.026428532790109358
# NRMSE: 0.04204749544994647
# R2 score: 0.9288892486590629
#
#
# C1 Prediction Scores
# TiO2:
# RMSE: 0.062056775503666575
# NRMSE: 0.12411355100733315
# R2 score: 0.6964922673770421
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 3, 'subsample': 1} : -0.15927434332916632 neg_root_mean_squared_error
#
# Final trees early stopping: 53
#
# Wells Test Scores
# Fe2O3:
# RMSE: 0.16012357464234264
# NRMSE: 0.04611827542535546
# R2 score: 0.9136487917401096
#
#
# C1 Prediction Scores
# Fe2O3:
# RMSE: 0.8836866495254722
# NRMSE: 0.11893494610033273
# R2 score: 0.2973765909065077
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 10, 'subsample': 0.5} : -0.009646726951520782 neg_root_mean_squared_error
#
# Final trees early stopping: 16
#
# Wells Test Scores
# MnO:
# RMSE: 0.0064228202253103
# NRMSE: 0.08770750000423734
# R2 score: 0.6324976573187637
#
#
# C1 Prediction Scores
# MnO:
# RMSE: 0.02767162290348588
# NRMSE: 0.15373123835269933
# R2 score: 0.2328911848539117
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 20, 'subsample': 0.5} : -0.3538462235994464 neg_root_mean_squared_error
#
# Final trees early stopping: 28
#
# Wells Test Scores
# MgO:
# RMSE: 0.3479483752621992
# NRMSE: 0.15599009013897697
# R2 score: 0.46871087871283545
#
#
# C1 Prediction Scores
# MgO:
# RMSE: 1.838231148404028
# NRMSE: 0.12774365173064822
# R2 score: 0.23323545200686258
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.01, 'max_depth': 5, 'subsample': 0.5} : -1.6983898913130915 neg_root_mean_squared_error
#
# Final trees early stopping: 448
#
# Wells Test Scores
# CaO:
# RMSE: 1.421585386930129
# NRMSE: 0.03606950471489115
# R2 score: 0.9634945443910958
#
#
# C1 Prediction Scores
# CaO:
# RMSE: 4.794255094208628
# NRMSE: 0.11387779321160636
# R2 score: 0.7627884974630472
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': None, 'subsample': 0.5} : -0.286145664942049 neg_root_mean_squared_error
#
# Final trees early stopping: 41
#
# Wells Test Scores
# Na2O:
# RMSE: 0.2989112321113898
# NRMSE: 0.09103849181823133
# R2 score: 0.7054366818749365
#
#
# C1 Prediction Scores
# Na2O:
# RMSE: 0.29348630818964555
# NRMSE: 0.14601308865156495
# R2 score: 0.5566722679784153
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.01, 'max_depth': 5, 'subsample': 0.5} : -0.16290625110727047 neg_root_mean_squared_error
#
# Final trees early stopping: 473
#
# Wells Test Scores
# K2O:
# RMSE: 0.10498933392440378
# NRMSE: 0.025063401072918937
# R2 score: 0.9667797374373661
#
#
# C1 Prediction Scores
# K2O:
# RMSE: 0.1744164002855742
# NRMSE: 0.05718570501166367
# R2 score: 0.8984458159598965
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 3, 'subsample': 1} : -0.08024728554357013 neg_root_mean_squared_error
#
# Final trees early stopping: 28
#
# Wells Test Scores
# P2O5:
# RMSE: 0.07263511524389481
# NRMSE: 0.1044418302186967
# R2 score: 0.4424560856172973
#
#
# C1 Prediction Scores
# P2O5:
# RMSE: 0.20459694574957862
# NRMSE: 0.15155329314783603
# R2 score: 0.1440789987037725
#
#
#
# Well TEST_3 validation
#    y_hat  rmse_XGB_TEST_3  nrmse_XGB_TEST_3  R2_XGB_TEST_3
# 0  Al2O3         0.272681          0.018941       0.984334
# 1   SiO2         1.611510          0.032139       0.960839
# 2   TiO2         0.026429          0.042047       0.928889
# 3  Fe2O3         0.160124          0.046118       0.913649
# 4    MnO         0.006423          0.087708       0.632498
# 5    MgO         0.347948          0.155990       0.468711
# 6    CaO         1.421585          0.036070       0.963495
# 7   Na2O         0.298911          0.091038       0.705437
# 8    K2O         0.104989          0.025063       0.966780
# 9   P2O5         0.072635          0.104442       0.442456
#
#
# C1 TEST_3 scores
#    y_hat  rmse_XGB_TEST_3  nrmse_XGB_TEST_3  R2_XGB_TEST_3
# 0  Al2O3         0.723676          0.046123       0.928969
# 1   SiO2         4.734344          0.090212       0.851427
# 2   TiO2         0.062057          0.124114       0.696492
# 3  Fe2O3         0.883687          0.118935       0.297377
# 4    MnO         0.027672          0.153731       0.232891
# 5    MgO         1.838231          0.127744       0.233235
# 6    CaO         4.794255          0.113878       0.762788
# 7   Na2O         0.293486          0.146013       0.556672
# 8    K2O         0.174416          0.057186       0.898446
# 9   P2O5         0.204597          0.151553       0.144079

# %%
XGB('TEST_4', 'C1_TEST_4')
# Out:
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.01, 'max_depth': 20, 'subsample': 0.5} : -0.3566463425975119 neg_root_mean_squared_error
#
# Final trees early stopping: 541
#
# Wells Test Scores
# Al2O3:
# RMSE: 0.40432292557261496
# NRMSE: 0.028085626474194013
# R2 score: 0.9641401460273247
#
#
# C1 Prediction Scores
# Al2O3:
# RMSE: 0.7763183130591269
# NRMSE: 0.04947854130395966
# R2 score: 0.9182589097194738
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 3, 'subsample': 0.5} : -1.9705281150431844 neg_root_mean_squared_error
#
# Final trees early stopping: 48
#
# Wells Test Scores
# SiO2:
# RMSE: 2.097709086472814
# NRMSE: 0.04183495211592589
# R2 score: 0.9292919296703168
#
#
# C1 Prediction Scores
# SiO2:
# RMSE: 5.2612872221965725
# NRMSE: 0.10025318639856273
# R2 score: 0.816513279625293
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.01, 'max_depth': 3, 'subsample': 0.5} : -0.026379329951705888 neg_root_mean_squared_error
#
# Final trees early stopping: 520
#
# Wells Test Scores
# TiO2:
# RMSE: 0.03214681016612234
# NRMSE: 0.05320117528526659
# R2 score: 0.8659962556026246
#
#
# C1 Prediction Scores
# TiO2:
# RMSE: 0.0624594739845582
# NRMSE: 0.1249189479691164
# R2 score: 0.6925404454087085
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 10, 'subsample': 0.5} : -0.1536021266105084 neg_root_mean_squared_error
#
# Final trees early stopping: 37
#
# Wells Test Scores
# Fe2O3:
# RMSE: 0.20929770391253963
# NRMSE: 0.060281249506782694
# R2 score: 0.8683946359072137
#
#
# C1 Prediction Scores
# Fe2O3:
# RMSE: 0.8661879658669501
# NRMSE: 0.11657980698074699
# R2 score: 0.32492765254435474
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 20, 'subsample': 0.5} : -0.005719666233561027 neg_root_mean_squared_error
#
# Final trees early stopping: 13
#
# Wells Test Scores
# MnO:
# RMSE: 0.005662370691932724
# NRMSE: 0.12776107156887914
# R2 score: 0.518007610605726
#
#
# C1 Prediction Scores
# MnO:
# RMSE: 0.031003356777976863
# NRMSE: 0.17224087098876034
# R2 score: 0.037046872074830595
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': None, 'subsample': 1} : -0.31368880806939736 neg_root_mean_squared_error
#
# Final trees early stopping: 62
#
# Wells Test Scores
# MgO:
# RMSE: 0.4152319323093944
# NRMSE: 0.12442300938775956
# R2 score: 0.28143303303042844
#
#
# C1 Prediction Scores
# MgO:
# RMSE: 1.786868330921836
# NRMSE: 0.1241743106964445
# R2 score: 0.2754858253209853
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.01, 'max_depth': 3, 'subsample': 0.5} : -1.5431591264727487 neg_root_mean_squared_error
#
# Final trees early stopping: 650
#
# Wells Test Scores
# CaO:
# RMSE: 2.228898317822994
# NRMSE: 0.05655323916725157
# R2 score: 0.9062241320634618
#
#
# C1 Prediction Scores
# CaO:
# RMSE: 5.040103244598531
# NRMSE: 0.11971741673630715
# R2 score: 0.7378364354131696
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 3, 'subsample': 0.5} : -0.2417075319973765 neg_root_mean_squared_error
#
# Final trees early stopping: 39
#
# Wells Test Scores
# Na2O:
# RMSE: 0.3239293167241987
# NRMSE: 0.09551126386150166
# R2 score: 0.6804362394928671
#
#
# C1 Prediction Scores
# Na2O:
# RMSE: 0.36416317819561195
# NRMSE: 0.18117571054508058
# R2 score: 0.3174393144442893
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 5, 'subsample': 0.5} : -0.12510269535537588 neg_root_mean_squared_error
#
# Final trees early stopping: 58
#
# Wells Test Scores
# K2O:
# RMSE: 0.1377365063574108
# NRMSE: 0.032880914395590974
# R2 score: 0.9434057418565741
#
#
# C1 Prediction Scores
# K2O:
# RMSE: 0.16963872288192525
# NRMSE: 0.05561925340390992
# R2 score: 0.903933233843769
#
#
#
# Final model best hyperparameters:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': None, 'subsample': 0.5} : -0.08377697033981422 neg_root_mean_squared_error
#
# Final trees early stopping: 16
#
# Wells Test Scores
# P2O5:
# RMSE: 0.07389067688549351
# NRMSE: 0.11798533681238685
# R2 score: 0.3777686478855813
#
#
# C1 Prediction Scores
# P2O5:
# RMSE: 0.20850742198850203
# NRMSE: 0.15444994221370523
# R2 score: 0.11104776244954728
#
#
#
# Well TEST_4 validation
#    y_hat  rmse_XGB_TEST_4  nrmse_XGB_TEST_4  R2_XGB_TEST_4
# 0  Al2O3         0.404323          0.028086       0.964140
# 1   SiO2         2.097709          0.041835       0.929292
# 2   TiO2         0.032147          0.053201       0.865996
# 3  Fe2O3         0.209298          0.060281       0.868395
# 4    MnO         0.005662          0.127761       0.518008
# 5    MgO         0.415232          0.124423       0.281433
# 6    CaO         2.228898          0.056553       0.906224
# 7   Na2O         0.323929          0.095511       0.680436
# 8    K2O         0.137737          0.032881       0.943406
# 9   P2O5         0.073891          0.117985       0.377769
#
#
# C1 TEST_4 scores
#    y_hat  rmse_XGB_TEST_4  nrmse_XGB_TEST_4  R2_XGB_TEST_4
# 0  Al2O3         0.776318          0.049479       0.918259
# 1   SiO2         5.261287          0.100253       0.816513
# 2   TiO2         0.062459          0.124919       0.692540
# 3  Fe2O3         0.866188          0.116580       0.324928
# 4    MnO         0.031003          0.172241       0.037047
# 5    MgO         1.786868          0.124174       0.275486
# 6    CaO         5.040103          0.119717       0.737836
# 7   Na2O         0.364163          0.181176       0.317439
# 8    K2O         0.169639          0.055619       0.903933
# 9   P2O5         0.208507          0.154450       0.111048

# %% [markdown]
# # LightGBM

# %%
def LGBM(test, C1_test):
    
    wells_scores = pd.DataFrame()
    C1_scores = pd.DataFrame()
    pred = pd.DataFrame(C1_depth)
    
    for col in Tests[test].iloc[:,1:-1]:
        X = Tests[test].drop([col], axis=1)
        y = Tests[test][col]
        
                
        X_train, X_test, y_train, y_test = train_test_split(
                                            X,
                                            y,
                                            train_size   = 0.7,
                                            random_state = 123,
                                            shuffle      = True
                                        )        
    
        # Evaluated Hyperparameters
    
        param_grid = {'n_estimators'     : [100, 500, 1000, 5000],
                      'max_depth'        : [-1, 1, 3, 5, 10, 20],
                      'subsample'        : [0.5, 1],
                      'learning_rate'    : [0.001, 0.01, 0.1],
                      'boosting_type'    : ['gbdt']
                     }

        # Grid
        
        grid = GridSearchCV(
                estimator  = LGBMRegressor(random_state=123),
                param_grid = param_grid,
                scoring    = 'neg_root_mean_squared_error',
                n_jobs     = multiprocessing.cpu_count() - 1,
                cv         = RepeatedKFold(n_splits=3, n_repeats=1, random_state=123), 
                refit      = True,
                verbose    = 0,
                return_train_score = True
               )

        grid.fit(X = X_train, y = y_train)

        print("Final model best hyperparameters: ")        
        print("")       
        print(grid.best_params_, ":", grid.best_score_, grid.scoring)
        print("")
    
        
        # Test scores
        
        final_model = grid.best_estimator_
        predictions = final_model.predict(X = X_test)
        
        rmse = mean_squared_error(
                y_true  = y_test,
                y_pred  = predictions,
                squared = False
               )
        
        nrmse = rmse/(y_test.max()-y_test.min())
        
        R2 = r2_score(y_test, predictions)        
        
        print("Wells Test Scores")
        print(f"{col}:")
        print(f"RMSE: {rmse}")
        print(f"NRMSE: {nrmse}")        
        print(f"R2 score: {R2}")
        print("")
        print("")
        
                  
        # Save well test validation
                
        wells_scores= wells_scores.append({"y_hat":col,f"rmse_LGBM_{test}": rmse, f"nrmse_LGBM_{test}": nrmse,
                                           f"R2_LGBM_{test}": R2}, ignore_index=True)
                
        wells_scores.to_excel(f"Wells_Mayor_scores_LGBM_{test}.xlsx")         
    
        
        # WELL C1 MAYOR ELEMENTS PREDICTIONS
    
        X_test_C1 = Tests[C1_test].drop([col], axis=1)
        y_test_C1 = Tests[C1_test][col]
    
        C1_predictions = final_model.predict(X_test_C1) 
    
        rmse_C1 = mean_squared_error(
                    y_true  = y_test_C1,
                    y_pred  = C1_predictions,
                    squared = False
                   )
                
        nrmse_C1 = rmse_C1/(y_test_C1.max()-y_test_C1.min())
        
        R2_C1 = r2_score(y_test_C1, C1_predictions) 
                
        
        print("C1 Prediction Scores")
        print(f"{col}:")
        print(f"RMSE: {rmse_C1}")
        print(f"NRMSE: {nrmse_C1}")        
        print(f"R2 score: {R2_C1}")
        print("")
        print("")
                
         
        # Save C1 predicted curves
        
        C1_pred = pd.DataFrame()

        C1_pred = C1_pred.assign(Predictions = C1_predictions.flatten().tolist())        
                
        pred = pd.concat([pred,C1_pred],axis=1)
        
        pred.columns = pred.columns.str.replace('Predictions', f"{col}")
        
        pred.to_excel(f"C1_Mayor_pred_LGBM_{test}.xlsx") 
        
        
        # Save C1 predictions scores
    
        C1_scores = C1_scores.append({'y_hat':col,f"rmse_LGBM_{test}": rmse_C1, f"nrmse_LGBM_{test}": nrmse_C1,
                                 f"R2_LGBM_{test}": R2_C1}, ignore_index=True)
        
        C1_scores.to_excel(f"C1_Mayor_scores_LGBM_{test}.xlsx")         
                
    
        print("")
        
    print(f"Well {test} validation")
    print(wells_scores)
    print("")
    print("")
    print(f"C1 {test} scores")
    print(C1_scores)

# %%
LGBM('TEST_1', 'C1_TEST_1')
# Out:
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 5000, 'subsample': 0.5} : -0.462656334114892 neg_root_mean_squared_error
#
# Wells Test Scores
# Al2O3:
# RMSE: 0.4300201289306756
# NRMSE: 0.03334743131570207
# R2 score: 0.9554889814230199
#
#
# C1 Prediction Scores
# Al2O3:
# RMSE: 1.1291267444652688
# NRMSE: 0.0719647383343065
# R2 score: 0.8270796315259903
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 5000, 'subsample': 0.5} : -2.2734174438611467 neg_root_mean_squared_error
#
# Wells Test Scores
# SiO2:
# RMSE: 1.8428091546276206
# NRMSE: 0.03841533075580601
# R2 score: 0.9455960397417151
#
#
# C1 Prediction Scores
# SiO2:
# RMSE: 4.369149475977669
# NRMSE: 0.08325361044164765
# R2 score: 0.8734639068125353
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 5000, 'subsample': 0.5} : -0.031551562285284655 neg_root_mean_squared_error
#
# Wells Test Scores
# TiO2:
# RMSE: 0.029573184786370412
# NRMSE: 0.043184510720302584
# R2 score: 0.9211220707654668
#
#
# C1 Prediction Scores
# TiO2:
# RMSE: 0.07949109101934468
# NRMSE: 0.15898218203868936
# R2 score: 0.5020012365903898
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 5000, 'subsample': 0.5} : -0.17256293304964174 neg_root_mean_squared_error
#
# Wells Test Scores
# Fe2O3:
# RMSE: 0.1584048971466423
# NRMSE: 0.06365374763782873
# R2 score: 0.8998728369798012
#
#
# C1 Prediction Scores
# Fe2O3:
# RMSE: 0.8634721275542396
# NRMSE: 0.1162142836546756
# R2 score: 0.3291542482111913
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100, 'subsample': 0.5} : -0.009424254298585908 neg_root_mean_squared_error
#
# Wells Test Scores
# MnO:
# RMSE: 0.00501239821028394
# NRMSE: 0.08582873647746474
# R2 score: 0.7077575633737709
#
#
# C1 Prediction Scores
# MnO:
# RMSE: 0.028127505170085398
# NRMSE: 0.15626391761158556
# R2 score: 0.20740717152385568
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100, 'subsample': 0.5} : -0.3671948472063388 neg_root_mean_squared_error
#
# Wells Test Scores
# MgO:
# RMSE: 0.2388602166418456
# NRMSE: 0.10567586598380113
# R2 score: 0.6815647992720715
#
#
# C1 Prediction Scores
# MgO:
# RMSE: 1.9254903935267649
# NRMSE: 0.13380753255919145
# R2 score: 0.15871238511632002
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 5000, 'subsample': 0.5} : -1.6092179218043858 neg_root_mean_squared_error
#
# Wells Test Scores
# CaO:
# RMSE: 1.5071685915516488
# NRMSE: 0.03824098441002052
# R2 score: 0.9615954659580024
#
#
# C1 Prediction Scores
# CaO:
# RMSE: 3.2053386428522397
# NRMSE: 0.0761363098064665
# R2 score: 0.893966937205104
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 1000, 'subsample': 0.5} : -0.34478227825720614 neg_root_mean_squared_error
#
# Wells Test Scores
# Na2O:
# RMSE: 0.24734922861984268
# NRMSE: 0.07175657766904048
# R2 score: 0.8557089849901067
#
#
# C1 Prediction Scores
# Na2O:
# RMSE: 0.7399533499639456
# NRMSE: 0.3681359950069381
# R2 score: -1.8181096691015073
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 5000, 'subsample': 0.5} : -0.23270037728370596 neg_root_mean_squared_error
#
# Wells Test Scores
# K2O:
# RMSE: 0.163313465844137
# NRMSE: 0.047427141841095005
# R2 score: 0.9006608935633207
#
#
# C1 Prediction Scores
# K2O:
# RMSE: 0.21165477277554176
# NRMSE: 0.06939500746739075
# R2 score: 0.8504524455461793
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 1000, 'subsample': 0.5} : -0.08471991055092698 neg_root_mean_squared_error
#
# Wells Test Scores
# P2O5:
# RMSE: 0.07062429376758614
# NRMSE: 0.13966478882984185
# R2 score: 0.4477307959272797
#
#
# C1 Prediction Scores
# P2O5:
# RMSE: 0.2283316834410944
# NRMSE: 0.1691345803267366
# R2 score: -0.06602587798121262
#
#
#
# Well TEST_1 validation
#    y_hat  rmse_LGBM_TEST_1  nrmse_LGBM_TEST_1  R2_LGBM_TEST_1
# 0  Al2O3          0.430020           0.033347        0.955489
# 1   SiO2          1.842809           0.038415        0.945596
# 2   TiO2          0.029573           0.043185        0.921122
# 3  Fe2O3          0.158405           0.063654        0.899873
# 4    MnO          0.005012           0.085829        0.707758
# 5    MgO          0.238860           0.105676        0.681565
# 6    CaO          1.507169           0.038241        0.961595
# 7   Na2O          0.247349           0.071757        0.855709
# 8    K2O          0.163313           0.047427        0.900661
# 9   P2O5          0.070624           0.139665        0.447731
#
#
# C1 TEST_1 scores
#    y_hat  rmse_LGBM_TEST_1  nrmse_LGBM_TEST_1  R2_LGBM_TEST_1
# 0  Al2O3          1.129127           0.071965        0.827080
# 1   SiO2          4.369149           0.083254        0.873464
# 2   TiO2          0.079491           0.158982        0.502001
# 3  Fe2O3          0.863472           0.116214        0.329154
# 4    MnO          0.028128           0.156264        0.207407
# 5    MgO          1.925490           0.133808        0.158712
# 6    CaO          3.205339           0.076136        0.893967
# 7   Na2O          0.739953           0.368136       -1.818110
# 8    K2O          0.211655           0.069395        0.850452
# 9   P2O5          0.228332           0.169135       -0.066026

# %%
LGBM('TEST_2', 'C1_TEST_2')
# Out:
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 0.5} : -0.47783777478635553 neg_root_mean_squared_error
#
# Wells Test Scores
# Al2O3:
# RMSE: 0.531085042242612
# NRMSE: 0.04743901955787947
# R2 score: 0.9234654829985812
#
#
# C1 Prediction Scores
# Al2O3:
# RMSE: 1.1216977188073995
# NRMSE: 0.07149125040200126
# R2 score: 0.8293475855632925
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 5000, 'subsample': 0.5} : -2.062160445300769 neg_root_mean_squared_error
#
# Wells Test Scores
# SiO2:
# RMSE: 1.9682231934442262
# NRMSE: 0.041526341835370656
# R2 score: 0.9385817377414043
#
#
# C1 Prediction Scores
# SiO2:
# RMSE: 5.2518399046562765
# NRMSE: 0.10007316891494429
# R2 score: 0.8171716359992929
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'subsample': 0.5} : -0.02831916909420529 neg_root_mean_squared_error
#
# Wells Test Scores
# TiO2:
# RMSE: 0.03493390230954354
# NRMSE: 0.057292172709378496
# R2 score: 0.8436410274229678
#
#
# C1 Prediction Scores
# TiO2:
# RMSE: 0.04444012071879171
# NRMSE: 0.08888024143758343
# R2 score: 0.8443526220604566
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 5000, 'subsample': 0.5} : -0.1573339002489842 neg_root_mean_squared_error
#
# Wells Test Scores
# Fe2O3:
# RMSE: 0.1634344938728875
# NRMSE: 0.05697162264192404
# R2 score: 0.9067414690356937
#
#
# C1 Prediction Scores
# Fe2O3:
# RMSE: 0.8687510800481665
# NRMSE: 0.11692477524201433
# R2 score: 0.3209265636359998
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.5} : -0.004023918029945216 neg_root_mean_squared_error
#
# Wells Test Scores
# MnO:
# RMSE: 0.004774180071487458
# NRMSE: 0.12219554828480823
# R2 score: 0.6367990362925091
#
#
# C1 Prediction Scores
# MnO:
# RMSE: 0.030877933152415157
# NRMSE: 0.1715440730689731
# R2 score: 0.044822337968726034
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 5000, 'subsample': 0.5} : -0.3307305318095666 neg_root_mean_squared_error
#
# Wells Test Scores
# MgO:
# RMSE: 0.231813123674784
# NRMSE: 0.09794782763966027
# R2 score: 0.6976565485180226
#
#
# C1 Prediction Scores
# MgO:
# RMSE: 1.9911022140395471
# NRMSE: 0.1383670753328386
# R2 score: 0.10040114590100058
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 5000, 'subsample': 0.5} : -1.7509868558600246 neg_root_mean_squared_error
#
# Wells Test Scores
# CaO:
# RMSE: 2.1068107329270425
# NRMSE: 0.050580788591652055
# R2 score: 0.9240905733384012
#
#
# C1 Prediction Scores
# CaO:
# RMSE: 4.302497612854545
# NRMSE: 0.10219709294191318
# R2 score: 0.8089554100541836
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 1000, 'subsample': 0.5} : -0.2526101095920979 neg_root_mean_squared_error
#
# Wells Test Scores
# Na2O:
# RMSE: 0.3207655323896426
# NRMSE: 0.09457841516650085
# R2 score: 0.7141581270854727
#
#
# C1 Prediction Scores
# Na2O:
# RMSE: 0.38048962991285523
# NRMSE: 0.18929832333972899
# R2 score: 0.2548651803455503
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'subsample': 0.5} : -0.1459650301766592 neg_root_mean_squared_error
#
# Wells Test Scores
# K2O:
# RMSE: 0.18378861299274923
# NRMSE: 0.06012254669526293
# R2 score: 0.8456558280603264
#
#
# C1 Prediction Scores
# K2O:
# RMSE: 0.2379242389355467
# NRMSE: 0.07800794719198254
# R2 score: 0.8110266506162175
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 500, 'subsample': 0.5} : -0.07845072207762037 neg_root_mean_squared_error
#
# Wells Test Scores
# P2O5:
# RMSE: 0.08304180132933388
# NRMSE: 0.12928818516165946
# R2 score: 0.40393465793791294
#
#
# C1 Prediction Scores
# P2O5:
# RMSE: 0.19350357146735517
# NRMSE: 0.14333597886470756
# R2 score: 0.23437984030966252
#
#
#
# Well TEST_2 validation
#    y_hat  rmse_LGBM_TEST_2  nrmse_LGBM_TEST_2  R2_LGBM_TEST_2
# 0  Al2O3          0.531085           0.047439        0.923465
# 1   SiO2          1.968223           0.041526        0.938582
# 2   TiO2          0.034934           0.057292        0.843641
# 3  Fe2O3          0.163434           0.056972        0.906741
# 4    MnO          0.004774           0.122196        0.636799
# 5    MgO          0.231813           0.097948        0.697657
# 6    CaO          2.106811           0.050581        0.924091
# 7   Na2O          0.320766           0.094578        0.714158
# 8    K2O          0.183789           0.060123        0.845656
# 9   P2O5          0.083042           0.129288        0.403935
#
#
# C1 TEST_2 scores
#    y_hat  rmse_LGBM_TEST_2  nrmse_LGBM_TEST_2  R2_LGBM_TEST_2
# 0  Al2O3          1.121698           0.071491        0.829348
# 1   SiO2          5.251840           0.100073        0.817172
# 2   TiO2          0.044440           0.088880        0.844353
# 3  Fe2O3          0.868751           0.116925        0.320927
# 4    MnO          0.030878           0.171544        0.044822
# 5    MgO          1.991102           0.138367        0.100401
# 6    CaO          4.302498           0.102197        0.808955
# 7   Na2O          0.380490           0.189298        0.254865
# 8    K2O          0.237924           0.078008        0.811027
# 9   P2O5          0.193504           0.143336        0.234380

# %%
LGBM('TEST_3', 'C1_TEST_3')
# Out:
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 5000, 'subsample': 0.5} : -0.46934863635872065 neg_root_mean_squared_error
#
# Wells Test Scores
# Al2O3:
# RMSE: 0.3625083366332196
# NRMSE: 0.025181044883969775
# R2 score: 0.9723133000072361
#
#
# C1 Prediction Scores
# Al2O3:
# RMSE: 0.9230871000989683
# NRMSE: 0.05883282983422361
# R2 score: 0.884429730082088
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 0.5} : -2.077486595033076 neg_root_mean_squared_error
#
# Wells Test Scores
# SiO2:
# RMSE: 1.7847663998933014
# NRMSE: 0.035593885424406474
# R2 score: 0.9519663051172209
#
#
# C1 Prediction Scores
# SiO2:
# RMSE: 4.8935008091239185
# NRMSE: 0.0932450611494649
# R2 score: 0.8412696607137587
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 5000, 'subsample': 0.5} : -0.036258533143212264 neg_root_mean_squared_error
#
# Wells Test Scores
# TiO2:
# RMSE: 0.026723816363389795
# NRMSE: 0.042517288260714985
# R2 score: 0.9272913438207924
#
#
# C1 Prediction Scores
# TiO2:
# RMSE: 0.06348249774485133
# NRMSE: 0.12696499548970266
# R2 score: 0.6823862022809275
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 0.5} : -0.17784288009508295 neg_root_mean_squared_error
#
# Wells Test Scores
# Fe2O3:
# RMSE: 0.16677627077483287
# NRMSE: 0.04803436350448237
# R2 score: 0.9063244218702999
#
#
# C1 Prediction Scores
# Fe2O3:
# RMSE: 0.8678446518529849
# NRMSE: 0.11680277952260901
# R2 score: 0.3223428731180056
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 5000, 'subsample': 0.5} : -0.008337271974209767 neg_root_mean_squared_error
#
# Wells Test Scores
# MnO:
# RMSE: 0.006079100773605356
# NRMSE: 0.08301380272573203
# R2 score: 0.6707792008008975
#
#
# C1 Prediction Scores
# MnO:
# RMSE: 0.02616719740570991
# NRMSE: 0.14537331892061062
# R2 score: 0.31403472154879974
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 1000, 'subsample': 0.5} : -0.3592521165781875 neg_root_mean_squared_error
#
# Wells Test Scores
# MgO:
# RMSE: 0.27226032509104864
# NRMSE: 0.12205808583016466
# R2 score: 0.6747105223956769
#
#
# C1 Prediction Scores
# MgO:
# RMSE: 1.8724586771544438
# NRMSE: 0.13012221522963474
# R2 score: 0.20441558446962638
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 5000, 'subsample': 0.5} : -1.8662513265246554 neg_root_mean_squared_error
#
# Wells Test Scores
# CaO:
# RMSE: 1.5499531537495705
# NRMSE: 0.03932654563069051
# R2 score: 0.9566040683754191
#
#
# C1 Prediction Scores
# CaO:
# RMSE: 4.991749618935267
# NRMSE: 0.11856887455903246
# R2 score: 0.7428425831899326
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 5000, 'subsample': 0.5} : -0.29924306706265713 neg_root_mean_squared_error
#
# Wells Test Scores
# Na2O:
# RMSE: 0.24811699705578139
# NRMSE: 0.075568244949756
# R2 score: 0.7970415084309431
#
#
# C1 Prediction Scores
# Na2O:
# RMSE: 0.3442174756297924
# NRMSE: 0.17125247543770766
# R2 score: 0.3901612181114431
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 0.5} : -0.20259689792282065 neg_root_mean_squared_error
#
# Wells Test Scores
# K2O:
# RMSE: 0.14112747877344484
# NRMSE: 0.03369041854723614
# R2 score: 0.9399744890324201
#
#
# C1 Prediction Scores
# K2O:
# RMSE: 0.275338019977861
# NRMSE: 0.09027476064847902
# R2 score: 0.7469213244313233
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5} : -0.08872269854369974 neg_root_mean_squared_error
#
# Wells Test Scores
# P2O5:
# RMSE: 0.07724252717003481
# NRMSE: 0.11106681501457283
# R2 score: 0.3694801427131752
#
#
# C1 Prediction Scores
# P2O5:
# RMSE: 0.199663536978526
# NRMSE: 0.14789891628038965
# R2 score: 0.18485867574275383
#
#
#
# Well TEST_3 validation
#    y_hat  rmse_LGBM_TEST_3  nrmse_LGBM_TEST_3  R2_LGBM_TEST_3
# 0  Al2O3          0.362508           0.025181        0.972313
# 1   SiO2          1.784766           0.035594        0.951966
# 2   TiO2          0.026724           0.042517        0.927291
# 3  Fe2O3          0.166776           0.048034        0.906324
# 4    MnO          0.006079           0.083014        0.670779
# 5    MgO          0.272260           0.122058        0.674711
# 6    CaO          1.549953           0.039327        0.956604
# 7   Na2O          0.248117           0.075568        0.797042
# 8    K2O          0.141127           0.033690        0.939974
# 9   P2O5          0.077243           0.111067        0.369480
#
#
# C1 TEST_3 scores
#    y_hat  rmse_LGBM_TEST_3  nrmse_LGBM_TEST_3  R2_LGBM_TEST_3
# 0  Al2O3          0.923087           0.058833        0.884430
# 1   SiO2          4.893501           0.093245        0.841270
# 2   TiO2          0.063482           0.126965        0.682386
# 3  Fe2O3          0.867845           0.116803        0.322343
# 4    MnO          0.026167           0.145373        0.314035
# 5    MgO          1.872459           0.130122        0.204416
# 6    CaO          4.991750           0.118569        0.742843
# 7   Na2O          0.344217           0.171252        0.390161
# 8    K2O          0.275338           0.090275        0.746921
# 9   P2O5          0.199664           0.147899        0.184859

# %%
LGBM('TEST_4', 'C1_TEST_4')
# Out:
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 0.5} : -0.5051796261982145 neg_root_mean_squared_error
#
# Wells Test Scores
# Al2O3:
# RMSE: 0.42552956949102544
# NRMSE: 0.029558711086005735
# R2 score: 0.9602798142579998
#
#
# C1 Prediction Scores
# Al2O3:
# RMSE: 1.08900383088063
# NRMSE: 0.0694075099350306
# R2 score: 0.8391505504964991
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 5000, 'subsample': 0.5} : -1.993316326830482 neg_root_mean_squared_error
#
# Wells Test Scores
# SiO2:
# RMSE: 2.0638253251579863
# NRMSE: 0.041159202775250266
# R2 score: 0.9315577400938343
#
#
# C1 Prediction Scores
# SiO2:
# RMSE: 5.6231183720701345
# NRMSE: 0.10714783483365348
# R2 score: 0.7904078235567822
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 0.5} : -0.03035106623736551 neg_root_mean_squared_error
#
# Wells Test Scores
# TiO2:
# RMSE: 0.03492092927026259
# NRMSE: 0.05779218745595795
# R2 score: 0.8418705549930707
#
#
# C1 Prediction Scores
# TiO2:
# RMSE: 0.061203424258751124
# NRMSE: 0.12240684851750225
# R2 score: 0.7047820290034186
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 1000, 'subsample': 0.5} : -0.16658313888657458 neg_root_mean_squared_error
#
# Wells Test Scores
# Fe2O3:
# RMSE: 0.18804838739028956
# NRMSE: 0.05416108991027977
# R2 score: 0.8937610205720754
#
#
# C1 Prediction Scores
# Fe2O3:
# RMSE: 0.8648285294879758
# NRMSE: 0.11639684111547455
# R2 score: 0.32704497069873273
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 1000, 'subsample': 0.5} : -0.0050610256906397965 neg_root_mean_squared_error
#
# Wells Test Scores
# MnO:
# RMSE: 0.004032613517409363
# NRMSE: 0.09098857214371306
# R2 score: 0.7555349442547935
#
#
# C1 Prediction Scores
# MnO:
# RMSE: 0.030104003745282697
# NRMSE: 0.16724446525157055
# R2 score: 0.09210373227921542
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 1000, 'subsample': 0.5} : -0.3325699749751278 neg_root_mean_squared_error
#
# Wells Test Scores
# MgO:
# RMSE: 0.37138564618701625
# NRMSE: 0.11128460059660208
# R2 score: 0.425174548928947
#
#
# C1 Prediction Scores
# MgO:
# RMSE: 1.953162393593292
# NRMSE: 0.1357305346485957
# R2 score: 0.13435765974153913
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 5000, 'subsample': 0.5} : -1.8901489805761391 neg_root_mean_squared_error
#
# Wells Test Scores
# CaO:
# RMSE: 2.213002859384792
# NRMSE: 0.05614992796389136
# R2 score: 0.9075568938425932
#
#
# C1 Prediction Scores
# CaO:
# RMSE: 6.089897630149692
# NRMSE: 0.14465315035985016
# R2 score: 0.6172515397668716
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 1000, 'subsample': 0.5} : -0.23442191541722898 neg_root_mean_squared_error
#
# Wells Test Scores
# Na2O:
# RMSE: 0.3004179502806207
# NRMSE: 0.08857888630813252
# R2 score: 0.7251417541186769
#
#
# C1 Prediction Scores
# Na2O:
# RMSE: 0.3660815859375631
# NRMSE: 0.1821301422574941
# R2 score: 0.31022892738160646
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 5000, 'subsample': 0.5} : -0.1683152944217365 neg_root_mean_squared_error
#
# Wells Test Scores
# K2O:
# RMSE: 0.18621703667219638
# NRMSE: 0.044454346953818114
# R2 score: 0.8965541510858988
#
#
# C1 Prediction Scores
# K2O:
# RMSE: 0.4845622365829187
# NRMSE: 0.15887286445341597
# R2 score: 0.21616922025124574
#
#
#
# Final model best hyperparameters:
#
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'subsample': 0.5} : -0.08402120267152317 neg_root_mean_squared_error
#
# Wells Test Scores
# P2O5:
# RMSE: 0.07438011431584074
# NRMSE: 0.11876684866885008
# R2 score: 0.3694982694104333
#
#
# C1 Prediction Scores
# P2O5:
# RMSE: 0.2028200470743591
# NRMSE: 0.1502370719069327
# R2 score: 0.1588815710587672
#
#
#
# Well TEST_4 validation
#    y_hat  rmse_LGBM_TEST_4  nrmse_LGBM_TEST_4  R2_LGBM_TEST_4
# 0  Al2O3          0.425530           0.029559        0.960280
# 1   SiO2          2.063825           0.041159        0.931558
# 2   TiO2          0.034921           0.057792        0.841871
# 3  Fe2O3          0.188048           0.054161        0.893761
# 4    MnO          0.004033           0.090989        0.755535
# 5    MgO          0.371386           0.111285        0.425175
# 6    CaO          2.213003           0.056150        0.907557
# 7   Na2O          0.300418           0.088579        0.725142
# 8    K2O          0.186217           0.044454        0.896554
# 9   P2O5          0.074380           0.118767        0.369498
#
#
# C1 TEST_4 scores
#    y_hat  rmse_LGBM_TEST_4  nrmse_LGBM_TEST_4  R2_LGBM_TEST_4
# 0  Al2O3          1.089004           0.069408        0.839151
# 1   SiO2          5.623118           0.107148        0.790408
# 2   TiO2          0.061203           0.122407        0.704782
# 3  Fe2O3          0.864829           0.116397        0.327045
# 4    MnO          0.030104           0.167244        0.092104
# 5    MgO          1.953162           0.135731        0.134358
# 6    CaO          6.089898           0.144653        0.617252
# 7   Na2O          0.366082           0.182130        0.310229
# 8    K2O          0.484562           0.158873        0.216169
# 9   P2O5          0.202820           0.150237        0.158882
